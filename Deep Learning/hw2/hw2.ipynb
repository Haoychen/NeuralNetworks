# %% [markdown]
# # ECBM E6040 Homework 2 - Programming Problem

# %%
import numpy as np
import matplotlib.pyplot as plt
import theano
import theano.tensor as T
from hw2b import load_data, LogisticRegression, HiddenLayer, MLP, test_mlp
# %matplotlib inline
# Out:
# Using gpu device 0: GRID K520 (CNMeM is disabled, cuDNN Version is too old. Update to v5, was 3007.)

# %% [markdown]
# ### Problem b: Bullet 2: Comparison between _tanh_ and _softmax_

# %%
#tanh
test_mlp(n_epochs=500, n_hidden_layer=1, batch_size=100, verbose=True)
# Out:
# ...
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 732/732, validation error 81.041096 %
#      epoch 1, minibatch 732/732, test error of best model 81.009105 %
# epoch 2, minibatch 732/732, validation error 79.986301 %
#      epoch 2, minibatch 732/732, test error of best model 80.160850 %
# epoch 3, minibatch 732/732, validation error 79.000000 %
#      epoch 3, minibatch 732/732, test error of best model 79.027314 %
# epoch 4, minibatch 732/732, validation error 77.972603 %
#      epoch 4, minibatch 732/732, test error of best model 77.808801 %
# epoch 5, minibatch 732/732, validation error 76.383562 %
#      epoch 5, minibatch 732/732, test error of best model 76.141123 %
# epoch 6, minibatch 732/732, validation error 74.301370 %
#      epoch 6, minibatch 732/732, test error of best model 73.840668 %
# epoch 7, minibatch 732/732, validation error 71.534247 %
#      epoch 7, minibatch 732/732, test error of best model 71.065250 %
# ...

# %%
#softmax
test_mlp(n_epochs=500, n_hidden_layer=1, batch_size=100, activation_function='softmax', verbose=True)
# Out:
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 732/732, validation error 81.150685 %
#      epoch 1, minibatch 732/732, test error of best model 81.068285 %
# epoch 2, minibatch 732/732, validation error 81.150685 %
# epoch 3, minibatch 732/732, validation error 81.150685 %
# epoch 4, minibatch 732/732, validation error 81.150685 %
# epoch 5, minibatch 732/732, validation error 81.150685 %
# epoch 6, minibatch 732/732, validation error 81.150685 %
# epoch 7, minibatch 732/732, validation error 81.150685 %
# epoch 8, minibatch 732/732, validation error 81.150685 %
# epoch 9, minibatch 732/732, validation error 81.150685 %
# epoch 10, minibatch 732/732, validation error 81.150685 %
# epoch 11, minibatch 732/732, validation error 81.150685 %
# epoch 12, minibatch 732/732, validation error 81.150685 %
# epoch 13, minibatch 732/732, validation error 81.150685 %
# ...

# %% [markdown]
# 1. Parameters: n_epochs=500, n_hidden_layer=1, batch_size=100, earning_rate=0.01, L1_reg=0.00, L2_reg=0.0001, n_hidden=500
#
# 2. Result: If use tanh activation funtion, the accuracy is 90.19%; if use softmax activation function, the accuracy is 19.93%

# %% [markdown]
# ### Problem b: Bullet 3: Experiment with the number of hidden layers

# %%
# The number of hidden layers: [1, 3, 5, 7]
test_performance_bullet3 = []
for i in [1, 3, 5, 7]:
    temp_model = test_mlp(activation_function='tanh', batch_size=100, n_hidden=300, n_hidden_layer=i, L1_reg=0.00, 
                          L2_reg=0.001, learning_rate=0.01, n_epochs=500, verbose=True)
    test_performance_bullet3.append(temp_model)

# %% [markdown]
# .. loading data
# ... building the model
# ... training
# epoch 1, minibatch 732/732, validation error 81.136986 %
#      epoch 1, minibatch 732/732, test error of best model 81.066768 %
# epoch 2, minibatch 732/732, validation error 80.602740 %
#      epoch 2, minibatch 732/732, test error of best model 80.698027 %
# epoch 3, minibatch 732/732, validation error 79.643836 %
#      epoch 3, minibatch 732/732, test error of best model 79.959029 %
# epoch 4, minibatch 732/732, validation error 78.890411 %
#      epoch 4, minibatch 732/732, test error of best model 78.910470 %
# epoch 5, minibatch 732/732, validation error 77.534247 %
#      epoch 5, minibatch 732/732, test error of best model 77.500759 %
# epoch 6, minibatch 732/732, validation error 75.657534 %
#      epoch 6, minibatch 732/732, test error of best model 75.306525 %
# epoch 7, minibatch 732/732, validation error 73.205479 %
#      epoch 7, minibatch 732/732, test error of best model 73.031866 %
# epoch 8, minibatch 732/732, validation error 70.630137 %
#      epoch 8, minibatch 732/732, test error of best model 70.106222 %
# epoch 9, minibatch 732/732, validation error 66.890411 %
#      epoch 9, minibatch 732/732, test error of best model 66.716237 %
# epoch 10, minibatch 732/732, validation error 63.342466 %
#      epoch 10, minibatch 732/732, test error of best model 62.931715 %
# epoch 11, minibatch 732/732, validation error 59.506849 %
#      epoch 11, minibatch 732/732, test error of best model 59.400607 %
# epoch 12, minibatch 732/732, validation error 56.191781 %
#      epoch 12, minibatch 732/732, test error of best model 56.288316 %
# epoch 13, minibatch 732/732, validation error 53.369863 %
#      epoch 13, minibatch 732/732, test error of best model 53.298938 %
# epoch 14, minibatch 732/732, validation error 50.575342 %
#      epoch 14, minibatch 732/732, test error of best model 50.578149 %
# epoch 15, minibatch 732/732, validation error 47.945205 %
#      epoch 15, minibatch 732/732, test error of best model 48.028832 %
# epoch 16, minibatch 732/732, validation error 45.643836 %
#      epoch 16, minibatch 732/732, test error of best model 45.867982 %
# epoch 17, minibatch 732/732, validation error 43.767123 %
#      epoch 17, minibatch 732/732, test error of best model 44.019727 %
# epoch 18, minibatch 732/732, validation error 42.493151 %
#      epoch 18, minibatch 732/732, test error of best model 42.374810 %
# epoch 19, minibatch 732/732, validation error 40.917808 %
#      epoch 19, minibatch 732/732, test error of best model 40.951442 %
# epoch 20, minibatch 732/732, validation error 39.575342 %
#      epoch 20, minibatch 732/732, test error of best model 39.678300 %
# epoch 21, minibatch 732/732, validation error 38.438356 %
#      epoch 21, minibatch 732/732, test error of best model 38.637329 %
# epoch 22, minibatch 732/732, validation error 37.643836 %
#      epoch 22, minibatch 732/732, test error of best model 37.784522 %
# epoch 23, minibatch 732/732, validation error 36.712329 %
#      epoch 23, minibatch 732/732, test error of best model 36.931715 %
# epoch 24, minibatch 732/732, validation error 35.945205 %
#      epoch 24, minibatch 732/732, test error of best model 36.162367 %
# epoch 25, minibatch 732/732, validation error 35.452055 %
#      epoch 25, minibatch 732/732, test error of best model 35.452200 %
# epoch 26, minibatch 732/732, validation error 34.630137 %
#      epoch 26, minibatch 732/732, test error of best model 34.811836 %
# epoch 27, minibatch 732/732, validation error 33.863014 %
#      epoch 27, minibatch 732/732, test error of best model 34.257967 %
# epoch 28, minibatch 732/732, validation error 33.246575 %
#      epoch 28, minibatch 732/732, test error of best model 33.701062 %
# epoch 29, minibatch 732/732, validation error 32.671233 %
#      epoch 29, minibatch 732/732, test error of best model 33.186646 %
# epoch 30, minibatch 732/732, validation error 32.260274 %
#      epoch 30, minibatch 732/732, test error of best model 32.720789 %
# epoch 31, minibatch 732/732, validation error 31.739726 %
#      epoch 31, minibatch 732/732, test error of best model 32.233687 %
# epoch 32, minibatch 732/732, validation error 31.397260 %
#      epoch 32, minibatch 732/732, test error of best model 31.799697 %
# epoch 33, minibatch 732/732, validation error 30.986301 %
#      epoch 33, minibatch 732/732, test error of best model 31.347496 %
# epoch 34, minibatch 732/732, validation error 30.643836 %
#      epoch 34, minibatch 732/732, test error of best model 31.001517 %
# epoch 35, minibatch 732/732, validation error 30.342466 %
#      epoch 35, minibatch 732/732, test error of best model 30.694992 %
# epoch 36, minibatch 732/732, validation error 29.972603 %
#      epoch 36, minibatch 732/732, test error of best model 30.365706 %
# epoch 37, minibatch 732/732, validation error 29.684932 %
#      epoch 37, minibatch 732/732, test error of best model 30.097117 %
# epoch 38, minibatch 732/732, validation error 29.383562 %
#      epoch 38, minibatch 732/732, test error of best model 29.834598 %
# epoch 39, minibatch 732/732, validation error 29.095890 %
#      epoch 39, minibatch 732/732, test error of best model 29.502276 %
# epoch 40, minibatch 732/732, validation error 28.767123 %
#      epoch 40, minibatch 732/732, test error of best model 29.226100 %
# epoch 41, minibatch 732/732, validation error 28.616438 %
#      epoch 41, minibatch 732/732, test error of best model 29.028832 %
# epoch 42, minibatch 732/732, validation error 28.342466 %
#      epoch 42, minibatch 732/732, test error of best model 28.779970 %
# epoch 43, minibatch 732/732, validation error 28.095890 %
#      epoch 43, minibatch 732/732, test error of best model 28.566009 %
# epoch 44, minibatch 732/732, validation error 27.849315 %
#      epoch 44, minibatch 732/732, test error of best model 28.368741 %
# epoch 45, minibatch 732/732, validation error 27.767123 %
#      epoch 45, minibatch 732/732, test error of best model 28.142640 %
# epoch 46, minibatch 732/732, validation error 27.630137 %
#      epoch 46, minibatch 732/732, test error of best model 27.952959 %
# epoch 47, minibatch 732/732, validation error 27.465753 %
#      epoch 47, minibatch 732/732, test error of best model 27.799697 %
# epoch 48, minibatch 732/732, validation error 27.232877 %
#      epoch 48, minibatch 732/732, test error of best model 27.631259 %
# epoch 49, minibatch 732/732, validation error 27.082192 %
#      epoch 49, minibatch 732/732, test error of best model 27.450683 %
# epoch 50, minibatch 732/732, validation error 26.904110 %
#      epoch 50, minibatch 732/732, test error of best model 27.318665 %
# epoch 51, minibatch 732/732, validation error 26.671233 %
#      epoch 51, minibatch 732/732, test error of best model 27.185129 %
# epoch 52, minibatch 732/732, validation error 26.561644 %
#      epoch 52, minibatch 732/732, test error of best model 27.036419 %
# epoch 53, minibatch 732/732, validation error 26.424658 %
#      epoch 53, minibatch 732/732, test error of best model 26.915023 %
# epoch 54, minibatch 732/732, validation error 26.369863 %
#      epoch 54, minibatch 732/732, test error of best model 26.783005 %
# epoch 55, minibatch 732/732, validation error 26.301370 %
#      epoch 55, minibatch 732/732, test error of best model 26.643399 %
# epoch 56, minibatch 732/732, validation error 26.136986 %
#      epoch 56, minibatch 732/732, test error of best model 26.532625 %
# epoch 57, minibatch 732/732, validation error 26.095890 %
#      epoch 57, minibatch 732/732, test error of best model 26.409712 %
# epoch 58, minibatch 732/732, validation error 26.054795 %
#      epoch 58, minibatch 732/732, test error of best model 26.280728 %
# epoch 59, minibatch 732/732, validation error 26.013699 %
#      epoch 59, minibatch 732/732, test error of best model 26.163885 %
# epoch 60, minibatch 732/732, validation error 25.958904 %
#      epoch 60, minibatch 732/732, test error of best model 26.044006 %
# epoch 61, minibatch 732/732, validation error 25.835616 %
#      epoch 61, minibatch 732/732, test error of best model 25.933232 %
# epoch 62, minibatch 732/732, validation error 25.794521 %
#      epoch 62, minibatch 732/732, test error of best model 25.827011 %
# epoch 63, minibatch 732/732, validation error 25.767123 %
#      epoch 63, minibatch 732/732, test error of best model 25.694992 %
# epoch 64, minibatch 732/732, validation error 25.657534 %
#      epoch 64, minibatch 732/732, test error of best model 25.605463 %
# epoch 65, minibatch 732/732, validation error 25.520548 %
#      epoch 65, minibatch 732/732, test error of best model 25.528073 %
# epoch 66, minibatch 732/732, validation error 25.342466 %
#      epoch 66, minibatch 732/732, test error of best model 25.408194 %
# epoch 67, minibatch 732/732, validation error 25.191781 %
#      epoch 67, minibatch 732/732, test error of best model 25.320182 %
# epoch 68, minibatch 732/732, validation error 25.136986 %
#      epoch 68, minibatch 732/732, test error of best model 25.223065 %
# epoch 69, minibatch 732/732, validation error 25.068493 %
#      epoch 69, minibatch 732/732, test error of best model 25.119879 %
# epoch 70, minibatch 732/732, validation error 25.027397 %
#      epoch 70, minibatch 732/732, test error of best model 25.013657 %
# epoch 71, minibatch 732/732, validation error 24.917808 %
#      epoch 71, minibatch 732/732, test error of best model 24.911988 %
# epoch 72, minibatch 732/732, validation error 24.835616 %
#      epoch 72, minibatch 732/732, test error of best model 24.828528 %
# epoch 73, minibatch 732/732, validation error 24.794521 %
#      epoch 73, minibatch 732/732, test error of best model 24.742033 %
# epoch 74, minibatch 732/732, validation error 24.616438 %
#      epoch 74, minibatch 732/732, test error of best model 24.679818 %
# epoch 75, minibatch 732/732, validation error 24.547945 %
#      epoch 75, minibatch 732/732, test error of best model 24.581184 %
# epoch 76, minibatch 732/732, validation error 24.410959 %
#      epoch 76, minibatch 732/732, test error of best model 24.479514 %
# epoch 77, minibatch 732/732, validation error 24.369863 %
#      epoch 77, minibatch 732/732, test error of best model 24.424886 %
# epoch 78, minibatch 732/732, validation error 24.328767 %
#      epoch 78, minibatch 732/732, test error of best model 24.352049 %
# epoch 79, minibatch 732/732, validation error 24.191781 %
#      epoch 79, minibatch 732/732, test error of best model 24.276176 %
# epoch 80, minibatch 732/732, validation error 24.082192 %
#      epoch 80, minibatch 732/732, test error of best model 24.172989 %
# epoch 81, minibatch 732/732, validation error 23.986301 %
#      epoch 81, minibatch 732/732, test error of best model 24.075873 %
# epoch 82, minibatch 732/732, validation error 23.917808 %
#      epoch 82, minibatch 732/732, test error of best model 24.001517 %
# epoch 83, minibatch 732/732, validation error 23.876712 %
#      epoch 83, minibatch 732/732, test error of best model 23.921093 %
# epoch 84, minibatch 732/732, validation error 23.808219 %
#      epoch 84, minibatch 732/732, test error of best model 23.842185 %
# epoch 85, minibatch 732/732, validation error 23.712329 %
#      epoch 85, minibatch 732/732, test error of best model 23.745068 %
# epoch 86, minibatch 732/732, validation error 23.589041 %
#      epoch 86, minibatch 732/732, test error of best model 23.685888 %
# epoch 87, minibatch 732/732, validation error 23.534247 %
#      epoch 87, minibatch 732/732, test error of best model 23.619120 %
# epoch 88, minibatch 732/732, validation error 23.506849 %
#      epoch 88, minibatch 732/732, test error of best model 23.531108 %
# epoch 89, minibatch 732/732, validation error 23.369863 %
#      epoch 89, minibatch 732/732, test error of best model 23.464340 %
# epoch 90, minibatch 732/732, validation error 23.397260 %
# epoch 91, minibatch 732/732, validation error 23.315068 %
#      epoch 91, minibatch 732/732, test error of best model 23.342944 %
# epoch 92, minibatch 732/732, validation error 23.287671 %
#      epoch 92, minibatch 732/732, test error of best model 23.271624 %
# epoch 93, minibatch 732/732, validation error 23.246575 %
#      epoch 93, minibatch 732/732, test error of best model 23.182094 %
# epoch 94, minibatch 732/732, validation error 23.191781 %
#      epoch 94, minibatch 732/732, test error of best model 23.088012 %
# epoch 95, minibatch 732/732, validation error 23.178082 %
#      epoch 95, minibatch 732/732, test error of best model 23.022762 %
# epoch 96, minibatch 732/732, validation error 23.082192 %
#      epoch 96, minibatch 732/732, test error of best model 22.963581 %
# epoch 97, minibatch 732/732, validation error 23.013699 %
#      epoch 97, minibatch 732/732, test error of best model 22.904401 %
# epoch 98, minibatch 732/732, validation error 22.876712 %
#      epoch 98, minibatch 732/732, test error of best model 22.854325 %
# epoch 99, minibatch 732/732, validation error 22.808219 %
#      epoch 99, minibatch 732/732, test error of best model 22.795144 %
# epoch 100, minibatch 732/732, validation error 22.794521 %
#      epoch 100, minibatch 732/732, test error of best model 22.760243 %
# epoch 101, minibatch 732/732, validation error 22.767123 %
#      epoch 101, minibatch 732/732, test error of best model 22.723824 %
# epoch 102, minibatch 732/732, validation error 22.657534 %
#      epoch 102, minibatch 732/732, test error of best model 22.678300 %
# epoch 103, minibatch 732/732, validation error 22.589041 %
#      epoch 103, minibatch 732/732, test error of best model 22.616085 %
# epoch 104, minibatch 732/732, validation error 22.561644 %
#      epoch 104, minibatch 732/732, test error of best model 22.561457 %
# epoch 105, minibatch 732/732, validation error 22.479452 %
#      epoch 105, minibatch 732/732, test error of best model 22.496206 %
# epoch 106, minibatch 732/732, validation error 22.424658 %
#      epoch 106, minibatch 732/732, test error of best model 22.455235 %
# epoch 107, minibatch 732/732, validation error 22.356164 %
#      epoch 107, minibatch 732/732, test error of best model 22.394537 %
# epoch 108, minibatch 732/732, validation error 22.315068 %
#      epoch 108, minibatch 732/732, test error of best model 22.345979 %
# epoch 109, minibatch 732/732, validation error 22.273973 %
#      epoch 109, minibatch 732/732, test error of best model 22.288316 %
# epoch 110, minibatch 732/732, validation error 22.246575 %
#      epoch 110, minibatch 732/732, test error of best model 22.241275 %
# epoch 111, minibatch 732/732, validation error 22.164384 %
#      epoch 111, minibatch 732/732, test error of best model 22.194234 %
# epoch 112, minibatch 732/732, validation error 22.109589 %
#      epoch 112, minibatch 732/732, test error of best model 22.144158 %
# epoch 113, minibatch 732/732, validation error 22.054795 %
#      epoch 113, minibatch 732/732, test error of best model 22.113809 %
# epoch 114, minibatch 732/732, validation error 22.041096 %
#      epoch 114, minibatch 732/732, test error of best model 22.066768 %
# epoch 115, minibatch 732/732, validation error 21.931507 %
#      epoch 115, minibatch 732/732, test error of best model 22.024279 %
# epoch 116, minibatch 732/732, validation error 21.904110 %
#      epoch 116, minibatch 732/732, test error of best model 21.990895 %
# epoch 117, minibatch 732/732, validation error 21.863014 %
#      epoch 117, minibatch 732/732, test error of best model 21.945372 %
# epoch 118, minibatch 732/732, validation error 21.835616 %
#      epoch 118, minibatch 732/732, test error of best model 21.904401 %
# epoch 119, minibatch 732/732, validation error 21.739726 %
#      epoch 119, minibatch 732/732, test error of best model 21.863429 %
# epoch 120, minibatch 732/732, validation error 21.698630 %
#      epoch 120, minibatch 732/732, test error of best model 21.828528 %
# epoch 121, minibatch 732/732, validation error 21.643836 %
#      epoch 121, minibatch 732/732, test error of best model 21.781487 %
# epoch 122, minibatch 732/732, validation error 21.575342 %
#      epoch 122, minibatch 732/732, test error of best model 21.732929 %
# epoch 123, minibatch 732/732, validation error 21.479452 %
#      epoch 123, minibatch 732/732, test error of best model 21.690440 %
# epoch 124, minibatch 732/732, validation error 21.410959 %
#      epoch 124, minibatch 732/732, test error of best model 21.652504 %
# epoch 125, minibatch 732/732, validation error 21.383562 %
#      epoch 125, minibatch 732/732, test error of best model 21.619120 %
# epoch 126, minibatch 732/732, validation error 21.287671 %
#      epoch 126, minibatch 732/732, test error of best model 21.584219 %
# epoch 127, minibatch 732/732, validation error 21.260274 %
#      epoch 127, minibatch 732/732, test error of best model 21.555387 %
# epoch 128, minibatch 732/732, validation error 21.232877 %
#      epoch 128, minibatch 732/732, test error of best model 21.517451 %
# epoch 129, minibatch 732/732, validation error 21.191781 %
#      epoch 129, minibatch 732/732, test error of best model 21.482549 %
# epoch 130, minibatch 732/732, validation error 21.164384 %
#      epoch 130, minibatch 732/732, test error of best model 21.452200 %
# epoch 131, minibatch 732/732, validation error 21.150685 %
#      epoch 131, minibatch 732/732, test error of best model 21.412747 %
# epoch 132, minibatch 732/732, validation error 21.123288 %
#      epoch 132, minibatch 732/732, test error of best model 21.389985 %
# epoch 133, minibatch 732/732, validation error 21.095890 %
#      epoch 133, minibatch 732/732, test error of best model 21.361153 %
# epoch 134, minibatch 732/732, validation error 21.068493 %
#      epoch 134, minibatch 732/732, test error of best model 21.320182 %
# epoch 135, minibatch 732/732, validation error 21.027397 %
#      epoch 135, minibatch 732/732, test error of best model 21.285281 %
# epoch 136, minibatch 732/732, validation error 20.986301 %
#      epoch 136, minibatch 732/732, test error of best model 21.261002 %
# epoch 137, minibatch 732/732, validation error 20.917808 %
#      epoch 137, minibatch 732/732, test error of best model 21.236722 %
# epoch 138, minibatch 732/732, validation error 20.890411 %
#      epoch 138, minibatch 732/732, test error of best model 21.204856 %
# epoch 139, minibatch 732/732, validation error 20.863014 %
#      epoch 139, minibatch 732/732, test error of best model 21.185129 %
# epoch 140, minibatch 732/732, validation error 20.876712 %
# epoch 141, minibatch 732/732, validation error 20.863014 %
# epoch 142, minibatch 732/732, validation error 20.863014 %
# epoch 143, minibatch 732/732, validation error 20.821918 %
#      epoch 143, minibatch 732/732, test error of best model 21.084977 %
# epoch 144, minibatch 732/732, validation error 20.849315 %
# epoch 145, minibatch 732/732, validation error 20.863014 %
# epoch 146, minibatch 732/732, validation error 20.821918 %
# epoch 147, minibatch 732/732, validation error 20.780822 %
#      epoch 147, minibatch 732/732, test error of best model 21.010622 %
# epoch 148, minibatch 732/732, validation error 20.780822 %
# epoch 149, minibatch 732/732, validation error 20.739726 %
#      epoch 149, minibatch 732/732, test error of best model 20.960546 %
# epoch 150, minibatch 732/732, validation error 20.671233 %
#      epoch 150, minibatch 732/732, test error of best model 20.936267 %
# epoch 151, minibatch 732/732, validation error 20.657534 %
#      epoch 151, minibatch 732/732, test error of best model 20.907436 %
# epoch 152, minibatch 732/732, validation error 20.630137 %
#      epoch 152, minibatch 732/732, test error of best model 20.887709 %
# epoch 153, minibatch 732/732, validation error 20.589041 %
#      epoch 153, minibatch 732/732, test error of best model 20.867982 %
# epoch 154, minibatch 732/732, validation error 20.602740 %
# epoch 155, minibatch 732/732, validation error 20.643836 %
# epoch 156, minibatch 732/732, validation error 20.616438 %
# epoch 157, minibatch 732/732, validation error 20.575342 %
#      epoch 157, minibatch 732/732, test error of best model 20.817906 %
# epoch 158, minibatch 732/732, validation error 20.547945 %
#      epoch 158, minibatch 732/732, test error of best model 20.799697 %
# epoch 159, minibatch 732/732, validation error 20.506849 %
#      epoch 159, minibatch 732/732, test error of best model 20.776935 %
# epoch 160, minibatch 732/732, validation error 20.479452 %
#      epoch 160, minibatch 732/732, test error of best model 20.757208 %
# epoch 161, minibatch 732/732, validation error 20.438356 %
#      epoch 161, minibatch 732/732, test error of best model 20.714719 %
# epoch 162, minibatch 732/732, validation error 20.424658 %
#      epoch 162, minibatch 732/732, test error of best model 20.696510 %
# epoch 163, minibatch 732/732, validation error 20.342466 %
#      epoch 163, minibatch 732/732, test error of best model 20.675266 %
# epoch 164, minibatch 732/732, validation error 20.328767 %
#      epoch 164, minibatch 732/732, test error of best model 20.640364 %
# epoch 165, minibatch 732/732, validation error 20.273973 %
#      epoch 165, minibatch 732/732, test error of best model 20.634294 %
# epoch 166, minibatch 732/732, validation error 20.246575 %
#      epoch 166, minibatch 732/732, test error of best model 20.626707 %
# epoch 167, minibatch 732/732, validation error 20.260274 %
# epoch 168, minibatch 732/732, validation error 20.260274 %
# epoch 169, minibatch 732/732, validation error 20.246575 %
#      epoch 169, minibatch 732/732, test error of best model 20.582701 %
# epoch 170, minibatch 732/732, validation error 20.246575 %
# epoch 171, minibatch 732/732, validation error 20.219178 %
#      epoch 171, minibatch 732/732, test error of best model 20.546282 %
# epoch 172, minibatch 732/732, validation error 20.219178 %
# epoch 173, minibatch 732/732, validation error 20.205479 %
#      epoch 173, minibatch 732/732, test error of best model 20.518968 %
# epoch 174, minibatch 732/732, validation error 20.150685 %
#      epoch 174, minibatch 732/732, test error of best model 20.508346 %
# epoch 175, minibatch 732/732, validation error 20.123288 %
#      epoch 175, minibatch 732/732, test error of best model 20.485584 %
# epoch 176, minibatch 732/732, validation error 20.095890 %
#      epoch 176, minibatch 732/732, test error of best model 20.479514 %
# epoch 177, minibatch 732/732, validation error 20.095890 %
#      epoch 177, minibatch 732/732, test error of best model 20.462822 %
# epoch 178, minibatch 732/732, validation error 20.082192 %
#      epoch 178, minibatch 732/732, test error of best model 20.449165 %
# epoch 179, minibatch 732/732, validation error 20.054795 %
#      epoch 179, minibatch 732/732, test error of best model 20.426404 %
# epoch 180, minibatch 732/732, validation error 20.013699 %
#      epoch 180, minibatch 732/732, test error of best model 20.406677 %
# epoch 181, minibatch 732/732, validation error 20.013699 %
# epoch 182, minibatch 732/732, validation error 20.000000 %
#      epoch 182, minibatch 732/732, test error of best model 20.383915 %
# epoch 183, minibatch 732/732, validation error 19.986301 %
#      epoch 183, minibatch 732/732, test error of best model 20.359636 %
# epoch 184, minibatch 732/732, validation error 19.958904 %
#      epoch 184, minibatch 732/732, test error of best model 20.338392 %
# epoch 185, minibatch 732/732, validation error 19.945205 %
#      epoch 185, minibatch 732/732, test error of best model 20.323217 %
# epoch 186, minibatch 732/732, validation error 19.945205 %
# epoch 187, minibatch 732/732, validation error 19.931507 %
#      epoch 187, minibatch 732/732, test error of best model 20.292868 %
# epoch 188, minibatch 732/732, validation error 19.931507 %
# epoch 189, minibatch 732/732, validation error 19.917808 %
#      epoch 189, minibatch 732/732, test error of best model 20.265554 %
# epoch 190, minibatch 732/732, validation error 19.931507 %
# epoch 191, minibatch 732/732, validation error 19.890411 %
#      epoch 191, minibatch 732/732, test error of best model 20.236722 %
# epoch 192, minibatch 732/732, validation error 19.904110 %
# epoch 193, minibatch 732/732, validation error 19.835616 %
#      epoch 193, minibatch 732/732, test error of best model 20.216995 %
# epoch 194, minibatch 732/732, validation error 19.876712 %
# epoch 195, minibatch 732/732, validation error 19.863014 %
# Optimization complete. Best validation score of 19.835616 % obtained at iteration 141276, with test performance 20.216995 %
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 732/732, validation error 81.150685 %
#      epoch 1, minibatch 732/732, test error of best model 81.068285 %
# epoch 2, minibatch 732/732, validation error 81.109589 %
#      epoch 2, minibatch 732/732, test error of best model 81.062215 %
# epoch 3, minibatch 732/732, validation error 80.191781 %
#      epoch 3, minibatch 732/732, test error of best model 80.514416 %
# epoch 4, minibatch 732/732, validation error 78.342466 %
#      epoch 4, minibatch 732/732, test error of best model 78.634294 %
# epoch 5, minibatch 732/732, validation error 72.027397 %
#      epoch 5, minibatch 732/732, test error of best model 72.015175 %
# epoch 6, minibatch 732/732, validation error 65.123288 %
#      epoch 6, minibatch 732/732, test error of best model 64.925645 %
# epoch 7, minibatch 732/732, validation error 60.041096 %
#      epoch 7, minibatch 732/732, test error of best model 60.050076 %
# epoch 8, minibatch 732/732, validation error 58.698630 %
#      epoch 8, minibatch 732/732, test error of best model 58.691958 %
# epoch 9, minibatch 732/732, validation error 54.698630 %
#      epoch 9, minibatch 732/732, test error of best model 54.423369 %
# epoch 10, minibatch 732/732, validation error 50.013699 %
#      epoch 10, minibatch 732/732, test error of best model 49.949924 %
# epoch 11, minibatch 732/732, validation error 46.424658 %
#      epoch 11, minibatch 732/732, test error of best model 46.414264 %
# epoch 12, minibatch 732/732, validation error 43.821918 %
#      epoch 12, minibatch 732/732, test error of best model 43.702580 %
# epoch 13, minibatch 732/732, validation error 41.753425 %
#      epoch 13, minibatch 732/732, test error of best model 41.411229 %
# epoch 14, minibatch 732/732, validation error 39.863014 %
#      epoch 14, minibatch 732/732, test error of best model 39.641882 %
# epoch 15, minibatch 732/732, validation error 38.356164 %
#      epoch 15, minibatch 732/732, test error of best model 38.236722 %
# epoch 16, minibatch 732/732, validation error 37.082192 %
#      epoch 16, minibatch 732/732, test error of best model 37.060698 %
# epoch 17, minibatch 732/732, validation error 36.287671 %
#      epoch 17, minibatch 732/732, test error of best model 36.036419 %
# epoch 18, minibatch 732/732, validation error 35.273973 %
#      epoch 18, minibatch 732/732, test error of best model 35.071320 %
# epoch 19, minibatch 732/732, validation error 34.150685 %
#      epoch 19, minibatch 732/732, test error of best model 34.191199 %
# epoch 20, minibatch 732/732, validation error 33.534247 %
#      epoch 20, minibatch 732/732, test error of best model 33.409712 %
# epoch 21, minibatch 732/732, validation error 32.890411 %
#      epoch 21, minibatch 732/732, test error of best model 32.731411 %
# epoch 22, minibatch 732/732, validation error 32.082192 %
#      epoch 22, minibatch 732/732, test error of best model 32.086495 %
# epoch 23, minibatch 732/732, validation error 31.547945 %
#      epoch 23, minibatch 732/732, test error of best model 31.444613 %
# epoch 24, minibatch 732/732, validation error 30.821918 %
#      epoch 24, minibatch 732/732, test error of best model 30.855842 %
# epoch 25, minibatch 732/732, validation error 30.095890 %
#      epoch 25, minibatch 732/732, test error of best model 30.297420 %
# epoch 26, minibatch 732/732, validation error 29.630137 %
#      epoch 26, minibatch 732/732, test error of best model 29.807284 %
# epoch 27, minibatch 732/732, validation error 29.136986 %
#      epoch 27, minibatch 732/732, test error of best model 29.288316 %
# epoch 28, minibatch 732/732, validation error 28.547945 %
#      epoch 28, minibatch 732/732, test error of best model 28.793627 %
# epoch 29, minibatch 732/732, validation error 28.123288 %
#      epoch 29, minibatch 732/732, test error of best model 28.338392 %
# epoch 30, minibatch 732/732, validation error 27.780822 %
#      epoch 30, minibatch 732/732, test error of best model 27.925645 %
# epoch 31, minibatch 732/732, validation error 27.342466 %
#      epoch 31, minibatch 732/732, test error of best model 27.491654 %
# epoch 32, minibatch 732/732, validation error 26.958904 %
#      epoch 32, minibatch 732/732, test error of best model 27.069803 %
# epoch 33, minibatch 732/732, validation error 26.369863 %
#      epoch 33, minibatch 732/732, test error of best model 26.650986 %
# epoch 34, minibatch 732/732, validation error 25.808219 %
#      epoch 34, minibatch 732/732, test error of best model 26.227618 %
# epoch 35, minibatch 732/732, validation error 25.328767 %
#      epoch 35, minibatch 732/732, test error of best model 25.848255 %
# epoch 36, minibatch 732/732, validation error 25.095890 %
#      epoch 36, minibatch 732/732, test error of best model 25.520486 %
# epoch 37, minibatch 732/732, validation error 24.780822 %
#      epoch 37, minibatch 732/732, test error of best model 25.154780 %
# epoch 38, minibatch 732/732, validation error 24.493151 %
#      epoch 38, minibatch 732/732, test error of best model 24.830046 %
# epoch 39, minibatch 732/732, validation error 24.164384 %
#      epoch 39, minibatch 732/732, test error of best model 24.458270 %
# epoch 40, minibatch 732/732, validation error 23.931507 %
#      epoch 40, minibatch 732/732, test error of best model 24.107739 %
# epoch 41, minibatch 732/732, validation error 23.561644 %
#      epoch 41, minibatch 732/732, test error of best model 23.820941 %
# epoch 42, minibatch 732/732, validation error 23.178082 %
#      epoch 42, minibatch 732/732, test error of best model 23.518968 %
# epoch 43, minibatch 732/732, validation error 22.958904 %
#      epoch 43, minibatch 732/732, test error of best model 23.251897 %
# epoch 44, minibatch 732/732, validation error 22.684932 %
#      epoch 44, minibatch 732/732, test error of best model 23.028832 %
# epoch 45, minibatch 732/732, validation error 22.479452 %
#      epoch 45, minibatch 732/732, test error of best model 22.801214 %
# epoch 46, minibatch 732/732, validation error 22.205479 %
#      epoch 46, minibatch 732/732, test error of best model 22.573596 %
# epoch 47, minibatch 732/732, validation error 21.835616 %
#      epoch 47, minibatch 732/732, test error of best model 22.317147 %
# epoch 48, minibatch 732/732, validation error 21.575342 %
#      epoch 48, minibatch 732/732, test error of best model 22.122914 %
# epoch 49, minibatch 732/732, validation error 21.369863 %
#      epoch 49, minibatch 732/732, test error of best model 21.901366 %
# epoch 50, minibatch 732/732, validation error 21.082192 %
#      epoch 50, minibatch 732/732, test error of best model 21.708649 %
# epoch 51, minibatch 732/732, validation error 20.931507 %
#      epoch 51, minibatch 732/732, test error of best model 21.540212 %
# epoch 52, minibatch 732/732, validation error 20.794521 %
#      epoch 52, minibatch 732/732, test error of best model 21.356601 %
# epoch 53, minibatch 732/732, validation error 20.616438 %
#      epoch 53, minibatch 732/732, test error of best model 21.191199 %
# epoch 54, minibatch 732/732, validation error 20.356164 %
#      epoch 54, minibatch 732/732, test error of best model 21.025797 %
# epoch 55, minibatch 732/732, validation error 20.232877 %
#      epoch 55, minibatch 732/732, test error of best model 20.860395 %
# epoch 56, minibatch 732/732, validation error 20.082192 %
#      epoch 56, minibatch 732/732, test error of best model 20.681335 %
# epoch 57, minibatch 732/732, validation error 19.904110 %
#      epoch 57, minibatch 732/732, test error of best model 20.543247 %
# epoch 58, minibatch 732/732, validation error 19.890411 %
#      epoch 58, minibatch 732/732, test error of best model 20.382398 %
# epoch 59, minibatch 732/732, validation error 19.794521 %
#      epoch 59, minibatch 732/732, test error of best model 20.244310 %
# epoch 60, minibatch 732/732, validation error 19.589041 %
#      epoch 60, minibatch 732/732, test error of best model 20.075873 %
# epoch 61, minibatch 732/732, validation error 19.479452 %
#      epoch 61, minibatch 732/732, test error of best model 19.901366 %
# epoch 62, minibatch 732/732, validation error 19.328767 %
#      epoch 62, minibatch 732/732, test error of best model 19.776935 %
# epoch 63, minibatch 732/732, validation error 19.219178 %
#      epoch 63, minibatch 732/732, test error of best model 19.657056 %
# epoch 64, minibatch 732/732, validation error 19.123288 %
#      epoch 64, minibatch 732/732, test error of best model 19.525038 %
# epoch 65, minibatch 732/732, validation error 18.904110 %
#      epoch 65, minibatch 732/732, test error of best model 19.397572 %
# epoch 66, minibatch 732/732, validation error 18.780822 %
#      epoch 66, minibatch 732/732, test error of best model 19.280728 %
# epoch 67, minibatch 732/732, validation error 18.575342 %
#      epoch 67, minibatch 732/732, test error of best model 19.159332 %
# epoch 68, minibatch 732/732, validation error 18.397260 %
#      epoch 68, minibatch 732/732, test error of best model 19.051593 %
# epoch 69, minibatch 732/732, validation error 18.287671 %
#      epoch 69, minibatch 732/732, test error of best model 18.965099 %
# epoch 70, minibatch 732/732, validation error 18.164384 %
#      epoch 70, minibatch 732/732, test error of best model 18.869499 %
# epoch 71, minibatch 732/732, validation error 18.068493 %
#      epoch 71, minibatch 732/732, test error of best model 18.757208 %
# epoch 72, minibatch 732/732, validation error 17.945205 %
#      epoch 72, minibatch 732/732, test error of best model 18.649469 %
# epoch 73, minibatch 732/732, validation error 17.726027 %
#      epoch 73, minibatch 732/732, test error of best model 18.569044 %
# epoch 74, minibatch 732/732, validation error 17.726027 %
#      epoch 74, minibatch 732/732, test error of best model 18.440061 %
# epoch 75, minibatch 732/732, validation error 17.643836 %
#      epoch 75, minibatch 732/732, test error of best model 18.368741 %
# epoch 76, minibatch 732/732, validation error 17.534247 %
#      epoch 76, minibatch 732/732, test error of best model 18.265554 %
# epoch 77, minibatch 732/732, validation error 17.438356 %
#      epoch 77, minibatch 732/732, test error of best model 18.169954 %
# epoch 78, minibatch 732/732, validation error 17.315068 %
#      epoch 78, minibatch 732/732, test error of best model 18.094082 %
# epoch 79, minibatch 732/732, validation error 17.150685 %
#      epoch 79, minibatch 732/732, test error of best model 18.027314 %
# epoch 80, minibatch 732/732, validation error 17.082192 %
#      epoch 80, minibatch 732/732, test error of best model 17.955994 %
# epoch 81, minibatch 732/732, validation error 17.000000 %
#      epoch 81, minibatch 732/732, test error of best model 17.860395 %
# epoch 82, minibatch 732/732, validation error 17.013699 %
# epoch 83, minibatch 732/732, validation error 16.904110 %
#      epoch 83, minibatch 732/732, test error of best model 17.728376 %
# epoch 84, minibatch 732/732, validation error 16.863014 %
#      epoch 84, minibatch 732/732, test error of best model 17.679818 %
# epoch 85, minibatch 732/732, validation error 16.794521 %
#      epoch 85, minibatch 732/732, test error of best model 17.637329 %
# epoch 86, minibatch 732/732, validation error 16.739726 %
#      epoch 86, minibatch 732/732, test error of best model 17.567527 %
# epoch 87, minibatch 732/732, validation error 16.616438 %
#      epoch 87, minibatch 732/732, test error of best model 17.499241 %
# epoch 88, minibatch 732/732, validation error 16.547945 %
#      epoch 88, minibatch 732/732, test error of best model 17.440061 %
# epoch 89, minibatch 732/732, validation error 16.479452 %
#      epoch 89, minibatch 732/732, test error of best model 17.352049 %
# epoch 90, minibatch 732/732, validation error 16.438356 %
#      epoch 90, minibatch 732/732, test error of best model 17.291351 %
# epoch 91, minibatch 732/732, validation error 16.424658 %
#      epoch 91, minibatch 732/732, test error of best model 17.224583 %
# epoch 92, minibatch 732/732, validation error 16.383562 %
#      epoch 92, minibatch 732/732, test error of best model 17.157815 %
# epoch 93, minibatch 732/732, validation error 16.369863 %
#      epoch 93, minibatch 732/732, test error of best model 17.091047 %
# epoch 94, minibatch 732/732, validation error 16.356164 %
#      epoch 94, minibatch 732/732, test error of best model 17.051593 %
# epoch 95, minibatch 732/732, validation error 16.315068 %
#      epoch 95, minibatch 732/732, test error of best model 17.001517 %
# epoch 96, minibatch 732/732, validation error 16.260274 %
#      epoch 96, minibatch 732/732, test error of best model 16.965099 %
# epoch 97, minibatch 732/732, validation error 16.273973 %
# epoch 98, minibatch 732/732, validation error 16.164384 %
#      epoch 98, minibatch 732/732, test error of best model 16.858877 %
# epoch 99, minibatch 732/732, validation error 16.123288 %
#      epoch 99, minibatch 732/732, test error of best model 16.789074 %
# epoch 100, minibatch 732/732, validation error 16.082192 %
#      epoch 100, minibatch 732/732, test error of best model 16.751138 %
# epoch 101, minibatch 732/732, validation error 16.054795 %
#      epoch 101, minibatch 732/732, test error of best model 16.708649 %
# epoch 102, minibatch 732/732, validation error 16.054795 %
# epoch 103, minibatch 732/732, validation error 15.945205 %
#      epoch 103, minibatch 732/732, test error of best model 16.631259 %
# epoch 104, minibatch 732/732, validation error 15.945205 %
# epoch 105, minibatch 732/732, validation error 15.945205 %
# epoch 106, minibatch 732/732, validation error 15.917808 %
#      epoch 106, minibatch 732/732, test error of best model 16.512898 %
# epoch 107, minibatch 732/732, validation error 15.904110 %
#      epoch 107, minibatch 732/732, test error of best model 16.465857 %
# epoch 108, minibatch 732/732, validation error 15.904110 %
# epoch 109, minibatch 732/732, validation error 15.835616 %
#      epoch 109, minibatch 732/732, test error of best model 16.409712 %
# epoch 110, minibatch 732/732, validation error 15.808219 %
#      epoch 110, minibatch 732/732, test error of best model 16.355083 %
# epoch 111, minibatch 732/732, validation error 15.726027 %
#      epoch 111, minibatch 732/732, test error of best model 16.321700 %
# epoch 112, minibatch 732/732, validation error 15.726027 %
# epoch 113, minibatch 732/732, validation error 15.794521 %
# epoch 114, minibatch 732/732, validation error 15.712329 %
#      epoch 114, minibatch 732/732, test error of best model 16.197269 %
# epoch 115, minibatch 732/732, validation error 15.739726 %
# epoch 116, minibatch 732/732, validation error 15.712329 %
#      epoch 116, minibatch 732/732, test error of best model 16.154780 %
# epoch 117, minibatch 732/732, validation error 15.657534 %
#      epoch 117, minibatch 732/732, test error of best model 16.113809 %
# epoch 118, minibatch 732/732, validation error 15.671233 %
# epoch 119, minibatch 732/732, validation error 15.657534 %
# epoch 120, minibatch 732/732, validation error 15.657534 %
# epoch 121, minibatch 732/732, validation error 15.616438 %
#      epoch 121, minibatch 732/732, test error of best model 15.986343 %
# epoch 122, minibatch 732/732, validation error 15.561644 %
#      epoch 122, minibatch 732/732, test error of best model 15.937785 %
# epoch 123, minibatch 732/732, validation error 15.493151 %
#      epoch 123, minibatch 732/732, test error of best model 15.899848 %
# epoch 124, minibatch 732/732, validation error 15.479452 %
#      epoch 124, minibatch 732/732, test error of best model 15.883156 %
# epoch 125, minibatch 732/732, validation error 15.438356 %
#      epoch 125, minibatch 732/732, test error of best model 15.846737 %
# epoch 126, minibatch 732/732, validation error 15.369863 %
#      epoch 126, minibatch 732/732, test error of best model 15.810319 %
# epoch 127, minibatch 732/732, validation error 15.287671 %
#      epoch 127, minibatch 732/732, test error of best model 15.770865 %
# epoch 128, minibatch 732/732, validation error 15.273973 %
#      epoch 128, minibatch 732/732, test error of best model 15.735964 %
# epoch 129, minibatch 732/732, validation error 15.287671 %
# epoch 130, minibatch 732/732, validation error 15.246575 %
#      epoch 130, minibatch 732/732, test error of best model 15.661608 %
# epoch 131, minibatch 732/732, validation error 15.191781 %
#      epoch 131, minibatch 732/732, test error of best model 15.634294 %
# epoch 132, minibatch 732/732, validation error 15.178082 %
#      epoch 132, minibatch 732/732, test error of best model 15.584219 %
# epoch 133, minibatch 732/732, validation error 15.109589 %
#      epoch 133, minibatch 732/732, test error of best model 15.544765 %
# epoch 134, minibatch 732/732, validation error 15.068493 %
#      epoch 134, minibatch 732/732, test error of best model 15.535660 %
# epoch 135, minibatch 732/732, validation error 15.027397 %
#      epoch 135, minibatch 732/732, test error of best model 15.505311 %
# epoch 136, minibatch 732/732, validation error 15.027397 %
# epoch 137, minibatch 732/732, validation error 14.972603 %
#      epoch 137, minibatch 732/732, test error of best model 15.447648 %
# epoch 138, minibatch 732/732, validation error 14.890411 %
#      epoch 138, minibatch 732/732, test error of best model 15.429439 %
# epoch 139, minibatch 732/732, validation error 14.835616 %
#      epoch 139, minibatch 732/732, test error of best model 15.417299 %
# epoch 140, minibatch 732/732, validation error 14.794521 %
#      epoch 140, minibatch 732/732, test error of best model 15.393020 %
# epoch 141, minibatch 732/732, validation error 14.698630 %
#      epoch 141, minibatch 732/732, test error of best model 15.382398 %
# epoch 142, minibatch 732/732, validation error 14.671233 %
#      epoch 142, minibatch 732/732, test error of best model 15.361153 %
# epoch 143, minibatch 732/732, validation error 14.643836 %
#      epoch 143, minibatch 732/732, test error of best model 15.345979 %
# epoch 144, minibatch 732/732, validation error 14.575342 %
#      epoch 144, minibatch 732/732, test error of best model 15.297420 %
# epoch 145, minibatch 732/732, validation error 14.561644 %
#      epoch 145, minibatch 732/732, test error of best model 15.279211 %
# epoch 146, minibatch 732/732, validation error 14.561644 %
# epoch 147, minibatch 732/732, validation error 14.506849 %
#      epoch 147, minibatch 732/732, test error of best model 15.245827 %
# epoch 148, minibatch 732/732, validation error 14.493151 %
#      epoch 148, minibatch 732/732, test error of best model 15.230653 %
# epoch 149, minibatch 732/732, validation error 14.520548 %
# epoch 150, minibatch 732/732, validation error 14.506849 %
# epoch 151, minibatch 732/732, validation error 14.479452 %
#      epoch 151, minibatch 732/732, test error of best model 15.128983 %
# epoch 152, minibatch 732/732, validation error 14.397260 %
#      epoch 152, minibatch 732/732, test error of best model 15.101669 %
# epoch 153, minibatch 732/732, validation error 14.301370 %
#      epoch 153, minibatch 732/732, test error of best model 15.088012 %
# epoch 154, minibatch 732/732, validation error 14.287671 %
#      epoch 154, minibatch 732/732, test error of best model 15.074355 %
# epoch 155, minibatch 732/732, validation error 14.246575 %
#      epoch 155, minibatch 732/732, test error of best model 15.056146 %
# epoch 156, minibatch 732/732, validation error 14.205479 %
#      epoch 156, minibatch 732/732, test error of best model 15.027314 %
# epoch 157, minibatch 732/732, validation error 14.136986 %
#      epoch 157, minibatch 732/732, test error of best model 14.995448 %
# epoch 158, minibatch 732/732, validation error 14.150685 %
# epoch 159, minibatch 732/732, validation error 14.136986 %
# epoch 160, minibatch 732/732, validation error 14.068493 %
#      epoch 160, minibatch 732/732, test error of best model 14.957511 %
# epoch 161, minibatch 732/732, validation error 14.000000 %
#      epoch 161, minibatch 732/732, test error of best model 14.949924 %
# epoch 162, minibatch 732/732, validation error 13.958904 %
#      epoch 162, minibatch 732/732, test error of best model 14.931715 %
# epoch 163, minibatch 732/732, validation error 13.972603 %
# epoch 164, minibatch 732/732, validation error 13.958904 %
#      epoch 164, minibatch 732/732, test error of best model 14.892261 %
# epoch 165, minibatch 732/732, validation error 13.917808 %
#      epoch 165, minibatch 732/732, test error of best model 14.892261 %
# epoch 166, minibatch 732/732, validation error 13.945205 %
# epoch 167, minibatch 732/732, validation error 13.931507 %
# epoch 168, minibatch 732/732, validation error 13.890411 %
#      epoch 168, minibatch 732/732, test error of best model 14.842185 %
# epoch 169, minibatch 732/732, validation error 13.876712 %
#      epoch 169, minibatch 732/732, test error of best model 14.819423 %
# epoch 170, minibatch 732/732, validation error 13.876712 %
# epoch 171, minibatch 732/732, validation error 13.849315 %
#      epoch 171, minibatch 732/732, test error of best model 14.781487 %
# epoch 172, minibatch 732/732, validation error 13.876712 %
# epoch 173, minibatch 732/732, validation error 13.849315 %
# epoch 174, minibatch 732/732, validation error 13.835616 %
#      epoch 174, minibatch 732/732, test error of best model 14.719272 %
# epoch 175, minibatch 732/732, validation error 13.808219 %
#      epoch 175, minibatch 732/732, test error of best model 14.704097 %
# epoch 176, minibatch 732/732, validation error 13.780822 %
#      epoch 176, minibatch 732/732, test error of best model 14.691958 %
# epoch 177, minibatch 732/732, validation error 13.780822 %
# epoch 178, minibatch 732/732, validation error 13.780822 %
# epoch 179, minibatch 732/732, validation error 13.726027 %
#      epoch 179, minibatch 732/732, test error of best model 14.629742 %
# epoch 180, minibatch 732/732, validation error 13.739726 %
# epoch 181, minibatch 732/732, validation error 13.657534 %
#      epoch 181, minibatch 732/732, test error of best model 14.613050 %
# epoch 182, minibatch 732/732, validation error 13.643836 %
#      epoch 182, minibatch 732/732, test error of best model 14.599393 %
# epoch 183, minibatch 732/732, validation error 13.616438 %
#      epoch 183, minibatch 732/732, test error of best model 14.584219 %
# epoch 184, minibatch 732/732, validation error 13.589041 %
#      epoch 184, minibatch 732/732, test error of best model 14.562974 %
# epoch 185, minibatch 732/732, validation error 13.589041 %
# epoch 186, minibatch 732/732, validation error 13.602740 %
# epoch 187, minibatch 732/732, validation error 13.589041 %
#      epoch 187, minibatch 732/732, test error of best model 14.528073 %
# epoch 188, minibatch 732/732, validation error 13.561644 %
#      epoch 188, minibatch 732/732, test error of best model 14.500759 %
# epoch 189, minibatch 732/732, validation error 13.534247 %
#      epoch 189, minibatch 732/732, test error of best model 14.473445 %
# epoch 190, minibatch 732/732, validation error 13.520548 %
#      epoch 190, minibatch 732/732, test error of best model 14.464340 %
# epoch 191, minibatch 732/732, validation error 13.506849 %
#      epoch 191, minibatch 732/732, test error of best model 14.455235 %
# epoch 192, minibatch 732/732, validation error 13.506849 %
# epoch 193, minibatch 732/732, validation error 13.506849 %
# epoch 194, minibatch 732/732, validation error 13.465753 %
#      epoch 194, minibatch 732/732, test error of best model 14.414264 %
# epoch 195, minibatch 732/732, validation error 13.465753 %
# epoch 196, minibatch 732/732, validation error 13.465753 %
# epoch 197, minibatch 732/732, validation error 13.424658 %
#      epoch 197, minibatch 732/732, test error of best model 14.367223 %
# epoch 198, minibatch 732/732, validation error 13.410959 %
#      epoch 198, minibatch 732/732, test error of best model 14.350531 %
# epoch 199, minibatch 732/732, validation error 13.397260 %
#      epoch 199, minibatch 732/732, test error of best model 14.339909 %
# epoch 200, minibatch 732/732, validation error 13.383562 %
#      epoch 200, minibatch 732/732, test error of best model 14.329287 %
# epoch 201, minibatch 732/732, validation error 13.369863 %
#      epoch 201, minibatch 732/732, test error of best model 14.323217 %
# epoch 202, minibatch 732/732, validation error 13.410959 %
# epoch 203, minibatch 732/732, validation error 13.369863 %
# epoch 204, minibatch 732/732, validation error 13.369863 %
# epoch 205, minibatch 732/732, validation error 13.369863 %
# epoch 206, minibatch 732/732, validation error 13.369863 %
# epoch 207, minibatch 732/732, validation error 13.342466 %
#      epoch 207, minibatch 732/732, test error of best model 14.242792 %
# epoch 208, minibatch 732/732, validation error 13.328767 %
#      epoch 208, minibatch 732/732, test error of best model 14.227618 %
# epoch 209, minibatch 732/732, validation error 13.301370 %
#      epoch 209, minibatch 732/732, test error of best model 14.213961 %
# epoch 210, minibatch 732/732, validation error 13.287671 %
#      epoch 210, minibatch 732/732, test error of best model 14.195751 %
# epoch 211, minibatch 732/732, validation error 13.246575 %
#      epoch 211, minibatch 732/732, test error of best model 14.197269 %
# epoch 212, minibatch 732/732, validation error 13.232877 %
#      epoch 212, minibatch 732/732, test error of best model 14.180577 %
# epoch 213, minibatch 732/732, validation error 13.205479 %
#      epoch 213, minibatch 732/732, test error of best model 14.176024 %
# epoch 214, minibatch 732/732, validation error 13.178082 %
#      epoch 214, minibatch 732/732, test error of best model 14.166920 %
# epoch 215, minibatch 732/732, validation error 13.178082 %
# epoch 216, minibatch 732/732, validation error 13.178082 %
# epoch 217, minibatch 732/732, validation error 13.178082 %
# epoch 218, minibatch 732/732, validation error 13.205479 %
# epoch 219, minibatch 732/732, validation error 13.191781 %
# epoch 220, minibatch 732/732, validation error 13.164384 %
#      epoch 220, minibatch 732/732, test error of best model 14.089530 %
# epoch 221, minibatch 732/732, validation error 13.164384 %
# epoch 222, minibatch 732/732, validation error 13.150685 %
#      epoch 222, minibatch 732/732, test error of best model 14.054628 %
# epoch 223, minibatch 732/732, validation error 13.109589 %
#      epoch 223, minibatch 732/732, test error of best model 14.054628 %
# epoch 224, minibatch 732/732, validation error 13.123288 %
# epoch 225, minibatch 732/732, validation error 13.123288 %
# epoch 226, minibatch 732/732, validation error 13.123288 %
# epoch 227, minibatch 732/732, validation error 13.123288 %
# epoch 228, minibatch 732/732, validation error 13.109589 %
# epoch 229, minibatch 732/732, validation error 13.095890 %
#      epoch 229, minibatch 732/732, test error of best model 13.986343 %
# epoch 230, minibatch 732/732, validation error 13.082192 %
#      epoch 230, minibatch 732/732, test error of best model 13.986343 %
# epoch 231, minibatch 732/732, validation error 13.054795 %
#      epoch 231, minibatch 732/732, test error of best model 13.963581 %
# epoch 232, minibatch 732/732, validation error 13.027397 %
#      epoch 232, minibatch 732/732, test error of best model 13.945372 %
# epoch 233, minibatch 732/732, validation error 13.013699 %
#      epoch 233, minibatch 732/732, test error of best model 13.940819 %
# epoch 234, minibatch 732/732, validation error 12.945205 %
#      epoch 234, minibatch 732/732, test error of best model 13.918058 %
# epoch 235, minibatch 732/732, validation error 12.917808 %
#      epoch 235, minibatch 732/732, test error of best model 13.902883 %
# epoch 236, minibatch 732/732, validation error 12.917808 %
# epoch 237, minibatch 732/732, validation error 12.931507 %
# epoch 238, minibatch 732/732, validation error 12.890411 %
#      epoch 238, minibatch 732/732, test error of best model 13.869499 %
# epoch 239, minibatch 732/732, validation error 12.904110 %
# epoch 240, minibatch 732/732, validation error 12.904110 %
# epoch 241, minibatch 732/732, validation error 12.890411 %
# epoch 242, minibatch 732/732, validation error 12.835616 %
#      epoch 242, minibatch 732/732, test error of best model 13.822458 %
# epoch 243, minibatch 732/732, validation error 12.767123 %
#      epoch 243, minibatch 732/732, test error of best model 13.810319 %
# epoch 244, minibatch 732/732, validation error 12.767123 %
# epoch 245, minibatch 732/732, validation error 12.753425 %
#      epoch 245, minibatch 732/732, test error of best model 13.790592 %
# epoch 246, minibatch 732/732, validation error 12.739726 %
#      epoch 246, minibatch 732/732, test error of best model 13.786039 %
# epoch 247, minibatch 732/732, validation error 12.684932 %
#      epoch 247, minibatch 732/732, test error of best model 13.784522 %
# epoch 248, minibatch 732/732, validation error 12.657534 %
#      epoch 248, minibatch 732/732, test error of best model 13.772382 %
# epoch 249, minibatch 732/732, validation error 12.671233 %
# epoch 250, minibatch 732/732, validation error 12.684932 %
# epoch 251, minibatch 732/732, validation error 12.630137 %
#      epoch 251, minibatch 732/732, test error of best model 13.735964 %
# epoch 252, minibatch 732/732, validation error 12.602740 %
#      epoch 252, minibatch 732/732, test error of best model 13.714719 %
# epoch 253, minibatch 732/732, validation error 12.602740 %
# epoch 254, minibatch 732/732, validation error 12.602740 %
# epoch 255, minibatch 732/732, validation error 12.589041 %
#      epoch 255, minibatch 732/732, test error of best model 13.672231 %
# epoch 256, minibatch 732/732, validation error 12.575342 %
#      epoch 256, minibatch 732/732, test error of best model 13.660091 %
# epoch 257, minibatch 732/732, validation error 12.547945 %
#      epoch 257, minibatch 732/732, test error of best model 13.649469 %
# epoch 258, minibatch 732/732, validation error 12.520548 %
#      epoch 258, minibatch 732/732, test error of best model 13.646434 %
# epoch 259, minibatch 732/732, validation error 12.520548 %
# epoch 260, minibatch 732/732, validation error 12.506849 %
#      epoch 260, minibatch 732/732, test error of best model 13.625190 %
# epoch 261, minibatch 732/732, validation error 12.479452 %
#      epoch 261, minibatch 732/732, test error of best model 13.617602 %
# epoch 262, minibatch 732/732, validation error 12.506849 %
# epoch 263, minibatch 732/732, validation error 12.479452 %
# epoch 264, minibatch 732/732, validation error 12.452055 %
#      epoch 264, minibatch 732/732, test error of best model 13.585736 %
# epoch 265, minibatch 732/732, validation error 12.452055 %
# epoch 266, minibatch 732/732, validation error 12.424658 %
#      epoch 266, minibatch 732/732, test error of best model 13.573596 %
# epoch 267, minibatch 732/732, validation error 12.424658 %
# epoch 268, minibatch 732/732, validation error 12.410959 %
#      epoch 268, minibatch 732/732, test error of best model 13.558422 %
# epoch 269, minibatch 732/732, validation error 12.397260 %
#      epoch 269, minibatch 732/732, test error of best model 13.537178 %
# epoch 270, minibatch 732/732, validation error 12.410959 %
# epoch 271, minibatch 732/732, validation error 12.438356 %
# epoch 272, minibatch 732/732, validation error 12.424658 %
# epoch 273, minibatch 732/732, validation error 12.410959 %
# epoch 274, minibatch 732/732, validation error 12.397260 %
# epoch 275, minibatch 732/732, validation error 12.342466 %
#      epoch 275, minibatch 732/732, test error of best model 13.496206 %
# epoch 276, minibatch 732/732, validation error 12.328767 %
#      epoch 276, minibatch 732/732, test error of best model 13.479514 %
# epoch 277, minibatch 732/732, validation error 12.315068 %
#      epoch 277, minibatch 732/732, test error of best model 13.471927 %
# epoch 278, minibatch 732/732, validation error 12.315068 %
# epoch 279, minibatch 732/732, validation error 12.315068 %
# epoch 280, minibatch 732/732, validation error 12.301370 %
#      epoch 280, minibatch 732/732, test error of best model 13.427921 %
# epoch 281, minibatch 732/732, validation error 12.287671 %
#      epoch 281, minibatch 732/732, test error of best model 13.423369 %
# epoch 282, minibatch 732/732, validation error 12.273973 %
#      epoch 282, minibatch 732/732, test error of best model 13.409712 %
# epoch 283, minibatch 732/732, validation error 12.273973 %
# epoch 284, minibatch 732/732, validation error 12.287671 %
# epoch 285, minibatch 732/732, validation error 12.287671 %
# epoch 286, minibatch 732/732, validation error 12.328767 %
# epoch 287, minibatch 732/732, validation error 12.328767 %
# epoch 288, minibatch 732/732, validation error 12.328767 %
# epoch 289, minibatch 732/732, validation error 12.328767 %
# epoch 290, minibatch 732/732, validation error 12.315068 %
# epoch 291, minibatch 732/732, validation error 12.301370 %
# epoch 292, minibatch 732/732, validation error 12.287671 %
# epoch 293, minibatch 732/732, validation error 12.301370 %
# epoch 294, minibatch 732/732, validation error 12.273973 %
# epoch 295, minibatch 732/732, validation error 12.260274 %
#      epoch 295, minibatch 732/732, test error of best model 13.288316 %
# epoch 296, minibatch 732/732, validation error 12.246575 %
#      epoch 296, minibatch 732/732, test error of best model 13.289833 %
# epoch 297, minibatch 732/732, validation error 12.232877 %
#      epoch 297, minibatch 732/732, test error of best model 13.283763 %
# epoch 298, minibatch 732/732, validation error 12.232877 %
# epoch 299, minibatch 732/732, validation error 12.246575 %
# epoch 300, minibatch 732/732, validation error 12.232877 %
# epoch 301, minibatch 732/732, validation error 12.232877 %
# epoch 302, minibatch 732/732, validation error 12.219178 %
#      epoch 302, minibatch 732/732, test error of best model 13.239757 %
# epoch 303, minibatch 732/732, validation error 12.219178 %
# epoch 304, minibatch 732/732, validation error 12.178082 %
#      epoch 304, minibatch 732/732, test error of best model 13.218513 %
# epoch 305, minibatch 732/732, validation error 12.178082 %
# epoch 306, minibatch 732/732, validation error 12.164384 %
#      epoch 306, minibatch 732/732, test error of best model 13.204856 %
# epoch 307, minibatch 732/732, validation error 12.164384 %
# epoch 308, minibatch 732/732, validation error 12.178082 %
# epoch 309, minibatch 732/732, validation error 12.164384 %
# epoch 310, minibatch 732/732, validation error 12.164384 %
# epoch 311, minibatch 732/732, validation error 12.150685 %
#      epoch 311, minibatch 732/732, test error of best model 13.169954 %
# epoch 312, minibatch 732/732, validation error 12.109589 %
#      epoch 312, minibatch 732/732, test error of best model 13.165402 %
# epoch 313, minibatch 732/732, validation error 12.095890 %
#      epoch 313, minibatch 732/732, test error of best model 13.154780 %
# epoch 314, minibatch 732/732, validation error 12.109589 %
# epoch 315, minibatch 732/732, validation error 12.095890 %
# epoch 316, minibatch 732/732, validation error 12.095890 %
# epoch 317, minibatch 732/732, validation error 12.095890 %
# epoch 318, minibatch 732/732, validation error 12.095890 %
# epoch 319, minibatch 732/732, validation error 12.095890 %
# epoch 320, minibatch 732/732, validation error 12.068493 %
#      epoch 320, minibatch 732/732, test error of best model 13.100152 %
# epoch 321, minibatch 732/732, validation error 12.041096 %
#      epoch 321, minibatch 732/732, test error of best model 13.083460 %
# epoch 322, minibatch 732/732, validation error 12.041096 %
# epoch 323, minibatch 732/732, validation error 12.041096 %
# epoch 324, minibatch 732/732, validation error 12.000000 %
#      epoch 324, minibatch 732/732, test error of best model 13.059181 %
# epoch 325, minibatch 732/732, validation error 12.000000 %
# epoch 326, minibatch 732/732, validation error 11.986301 %
#      epoch 326, minibatch 732/732, test error of best model 13.025797 %
# epoch 327, minibatch 732/732, validation error 11.986301 %
# epoch 328, minibatch 732/732, validation error 12.000000 %
# epoch 329, minibatch 732/732, validation error 12.000000 %
# epoch 330, minibatch 732/732, validation error 12.000000 %
# epoch 331, minibatch 732/732, validation error 12.000000 %
# epoch 332, minibatch 732/732, validation error 12.013699 %
# epoch 333, minibatch 732/732, validation error 12.000000 %
# epoch 334, minibatch 732/732, validation error 11.986301 %
# epoch 335, minibatch 732/732, validation error 11.986301 %
# epoch 336, minibatch 732/732, validation error 11.958904 %
#      epoch 336, minibatch 732/732, test error of best model 12.937785 %
# epoch 337, minibatch 732/732, validation error 11.945205 %
#      epoch 337, minibatch 732/732, test error of best model 12.931715 %
# epoch 338, minibatch 732/732, validation error 11.917808 %
#      epoch 338, minibatch 732/732, test error of best model 12.928680 %
# epoch 339, minibatch 732/732, validation error 11.876712 %
#      epoch 339, minibatch 732/732, test error of best model 12.922610 %
# epoch 340, minibatch 732/732, validation error 11.890411 %
# epoch 341, minibatch 732/732, validation error 11.876712 %
# epoch 342, minibatch 732/732, validation error 11.849315 %
#      epoch 342, minibatch 732/732, test error of best model 12.892261 %
# epoch 343, minibatch 732/732, validation error 11.835616 %
#      epoch 343, minibatch 732/732, test error of best model 12.880121 %
# epoch 344, minibatch 732/732, validation error 11.835616 %
# epoch 345, minibatch 732/732, validation error 11.835616 %
# epoch 346, minibatch 732/732, validation error 11.863014 %
# epoch 347, minibatch 732/732, validation error 11.821918 %
#      epoch 347, minibatch 732/732, test error of best model 12.857360 %
# epoch 348, minibatch 732/732, validation error 11.808219 %
#      epoch 348, minibatch 732/732, test error of best model 12.860395 %
# epoch 349, minibatch 732/732, validation error 11.780822 %
#      epoch 349, minibatch 732/732, test error of best model 12.854325 %
# epoch 350, minibatch 732/732, validation error 11.767123 %
#      epoch 350, minibatch 732/732, test error of best model 12.854325 %
# epoch 351, minibatch 732/732, validation error 11.767123 %
# epoch 352, minibatch 732/732, validation error 11.767123 %
# epoch 353, minibatch 732/732, validation error 11.753425 %
#      epoch 353, minibatch 732/732, test error of best model 12.827011 %
# epoch 354, minibatch 732/732, validation error 11.739726 %
#      epoch 354, minibatch 732/732, test error of best model 12.823976 %
# epoch 355, minibatch 732/732, validation error 11.712329 %
#      epoch 355, minibatch 732/732, test error of best model 12.817906 %
# epoch 356, minibatch 732/732, validation error 11.712329 %
# epoch 357, minibatch 732/732, validation error 11.712329 %
# epoch 358, minibatch 732/732, validation error 11.712329 %
# epoch 359, minibatch 732/732, validation error 11.712329 %
# epoch 360, minibatch 732/732, validation error 11.671233 %
#      epoch 360, minibatch 732/732, test error of best model 12.766313 %
# epoch 361, minibatch 732/732, validation error 11.643836 %
#      epoch 361, minibatch 732/732, test error of best model 12.763278 %
# epoch 362, minibatch 732/732, validation error 11.643836 %
# epoch 363, minibatch 732/732, validation error 11.616438 %
#      epoch 363, minibatch 732/732, test error of best model 12.742033 %
# epoch 364, minibatch 732/732, validation error 11.602740 %
#      epoch 364, minibatch 732/732, test error of best model 12.726859 %
# epoch 365, minibatch 732/732, validation error 11.602740 %
# epoch 366, minibatch 732/732, validation error 11.575342 %
#      epoch 366, minibatch 732/732, test error of best model 12.716237 %
# epoch 367, minibatch 732/732, validation error 11.589041 %
# epoch 368, minibatch 732/732, validation error 11.589041 %
# epoch 369, minibatch 732/732, validation error 11.575342 %
#      epoch 369, minibatch 732/732, test error of best model 12.713202 %
# epoch 370, minibatch 732/732, validation error 11.547945 %
#      epoch 370, minibatch 732/732, test error of best model 12.711684 %
# epoch 371, minibatch 732/732, validation error 11.547945 %
# epoch 372, minibatch 732/732, validation error 11.561644 %
# epoch 373, minibatch 732/732, validation error 11.561644 %
# epoch 374, minibatch 732/732, validation error 11.561644 %
# epoch 375, minibatch 732/732, validation error 11.561644 %
# epoch 376, minibatch 732/732, validation error 11.561644 %
# epoch 377, minibatch 732/732, validation error 11.547945 %
# epoch 378, minibatch 732/732, validation error 11.520548 %
#      epoch 378, minibatch 732/732, test error of best model 12.670713 %
# epoch 379, minibatch 732/732, validation error 11.520548 %
# epoch 380, minibatch 732/732, validation error 11.506849 %
#      epoch 380, minibatch 732/732, test error of best model 12.661608 %
# epoch 381, minibatch 732/732, validation error 11.479452 %
#      epoch 381, minibatch 732/732, test error of best model 12.655539 %
# epoch 382, minibatch 732/732, validation error 11.465753 %
#      epoch 382, minibatch 732/732, test error of best model 12.646434 %
# epoch 383, minibatch 732/732, validation error 11.452055 %
#      epoch 383, minibatch 732/732, test error of best model 12.646434 %
# epoch 384, minibatch 732/732, validation error 11.438356 %
#      epoch 384, minibatch 732/732, test error of best model 12.644917 %
# epoch 385, minibatch 732/732, validation error 11.438356 %
# epoch 386, minibatch 732/732, validation error 11.452055 %
# epoch 387, minibatch 732/732, validation error 11.452055 %
# epoch 388, minibatch 732/732, validation error 11.465753 %
# epoch 389, minibatch 732/732, validation error 11.438356 %
# epoch 390, minibatch 732/732, validation error 11.424658 %
#      epoch 390, minibatch 732/732, test error of best model 12.635812 %
# epoch 391, minibatch 732/732, validation error 11.424658 %
# epoch 392, minibatch 732/732, validation error 11.424658 %
# epoch 393, minibatch 732/732, validation error 11.397260 %
#      epoch 393, minibatch 732/732, test error of best model 12.625190 %
# epoch 394, minibatch 732/732, validation error 11.410959 %
# epoch 395, minibatch 732/732, validation error 11.410959 %
# epoch 396, minibatch 732/732, validation error 11.397260 %
# epoch 397, minibatch 732/732, validation error 11.397260 %
# epoch 398, minibatch 732/732, validation error 11.397260 %
# epoch 399, minibatch 732/732, validation error 11.397260 %
# epoch 400, minibatch 732/732, validation error 11.410959 %
# epoch 401, minibatch 732/732, validation error 11.410959 %
# epoch 402, minibatch 732/732, validation error 11.356164 %
#      epoch 402, minibatch 732/732, test error of best model 12.561457 %
# epoch 403, minibatch 732/732, validation error 11.356164 %
# epoch 404, minibatch 732/732, validation error 11.342466 %
#      epoch 404, minibatch 732/732, test error of best model 12.550835 %
# epoch 405, minibatch 732/732, validation error 11.328767 %
#      epoch 405, minibatch 732/732, test error of best model 12.552352 %
# epoch 406, minibatch 732/732, validation error 11.342466 %
# epoch 407, minibatch 732/732, validation error 11.328767 %
# epoch 408, minibatch 732/732, validation error 11.315068 %
#      epoch 408, minibatch 732/732, test error of best model 12.538695 %
# epoch 409, minibatch 732/732, validation error 11.328767 %
# epoch 410, minibatch 732/732, validation error 11.328767 %
# epoch 411, minibatch 732/732, validation error 11.315068 %
# epoch 412, minibatch 732/732, validation error 11.315068 %
# epoch 413, minibatch 732/732, validation error 11.315068 %
# epoch 414, minibatch 732/732, validation error 11.328767 %
# epoch 415, minibatch 732/732, validation error 11.315068 %
#      epoch 415, minibatch 732/732, test error of best model 12.481032 %
# epoch 416, minibatch 732/732, validation error 11.328767 %
# epoch 417, minibatch 732/732, validation error 11.315068 %
# epoch 418, minibatch 732/732, validation error 11.328767 %
# epoch 419, minibatch 732/732, validation error 11.315068 %
# epoch 420, minibatch 732/732, validation error 11.315068 %
# epoch 421, minibatch 732/732, validation error 11.301370 %
#      epoch 421, minibatch 732/732, test error of best model 12.455235 %
# epoch 422, minibatch 732/732, validation error 11.301370 %
# epoch 423, minibatch 732/732, validation error 11.301370 %
# epoch 424, minibatch 732/732, validation error 11.287671 %
#      epoch 424, minibatch 732/732, test error of best model 12.440061 %
# epoch 425, minibatch 732/732, validation error 11.273973 %
#      epoch 425, minibatch 732/732, test error of best model 12.433991 %
# epoch 426, minibatch 732/732, validation error 11.260274 %
#      epoch 426, minibatch 732/732, test error of best model 12.423369 %
# epoch 427, minibatch 732/732, validation error 11.260274 %
# epoch 428, minibatch 732/732, validation error 11.273973 %
# epoch 429, minibatch 732/732, validation error 11.273973 %
# epoch 430, minibatch 732/732, validation error 11.273973 %
# epoch 431, minibatch 732/732, validation error 11.273973 %
# epoch 432, minibatch 732/732, validation error 11.287671 %
# epoch 433, minibatch 732/732, validation error 11.301370 %
# epoch 434, minibatch 732/732, validation error 11.287671 %
# epoch 435, minibatch 732/732, validation error 11.287671 %
# epoch 436, minibatch 732/732, validation error 11.287671 %
# epoch 437, minibatch 732/732, validation error 11.301370 %
# epoch 438, minibatch 732/732, validation error 11.287671 %
# epoch 439, minibatch 732/732, validation error 11.287671 %
# epoch 440, minibatch 732/732, validation error 11.301370 %
# epoch 441, minibatch 732/732, validation error 11.301370 %
# epoch 442, minibatch 732/732, validation error 11.287671 %
# epoch 443, minibatch 732/732, validation error 11.273973 %
# epoch 444, minibatch 732/732, validation error 11.273973 %
# epoch 445, minibatch 732/732, validation error 11.273973 %
# epoch 446, minibatch 732/732, validation error 11.260274 %
# epoch 447, minibatch 732/732, validation error 11.260274 %
# epoch 448, minibatch 732/732, validation error 11.246575 %
#      epoch 448, minibatch 732/732, test error of best model 12.277693 %
# epoch 449, minibatch 732/732, validation error 11.246575 %
# epoch 450, minibatch 732/732, validation error 11.232877 %
#      epoch 450, minibatch 732/732, test error of best model 12.257967 %
# epoch 451, minibatch 732/732, validation error 11.219178 %
#      epoch 451, minibatch 732/732, test error of best model 12.261002 %
# epoch 452, minibatch 732/732, validation error 11.219178 %
# epoch 453, minibatch 732/732, validation error 11.191781 %
#      epoch 453, minibatch 732/732, test error of best model 12.253414 %
# epoch 454, minibatch 732/732, validation error 11.178082 %
#      epoch 454, minibatch 732/732, test error of best model 12.241275 %
# epoch 455, minibatch 732/732, validation error 11.178082 %
# epoch 456, minibatch 732/732, validation error 11.164384 %
#      epoch 456, minibatch 732/732, test error of best model 12.230653 %
# epoch 457, minibatch 732/732, validation error 11.136986 %
#      epoch 457, minibatch 732/732, test error of best model 12.220030 %
# epoch 458, minibatch 732/732, validation error 11.136986 %
# epoch 459, minibatch 732/732, validation error 11.136986 %
# epoch 460, minibatch 732/732, validation error 11.136986 %
# epoch 461, minibatch 732/732, validation error 11.123288 %
#      epoch 461, minibatch 732/732, test error of best model 12.203338 %
# epoch 462, minibatch 732/732, validation error 11.109589 %
#      epoch 462, minibatch 732/732, test error of best model 12.194234 %
# epoch 463, minibatch 732/732, validation error 11.095890 %
#      epoch 463, minibatch 732/732, test error of best model 12.189681 %
# epoch 464, minibatch 732/732, validation error 11.068493 %
#      epoch 464, minibatch 732/732, test error of best model 12.183612 %
# epoch 465, minibatch 732/732, validation error 11.068493 %
# epoch 466, minibatch 732/732, validation error 11.068493 %
# epoch 467, minibatch 732/732, validation error 11.068493 %
# epoch 468, minibatch 732/732, validation error 11.054795 %
#      epoch 468, minibatch 732/732, test error of best model 12.174507 %
# epoch 469, minibatch 732/732, validation error 11.054795 %
# epoch 470, minibatch 732/732, validation error 11.068493 %
# epoch 471, minibatch 732/732, validation error 11.054795 %
# epoch 472, minibatch 732/732, validation error 11.054795 %
# epoch 473, minibatch 732/732, validation error 11.054795 %
# epoch 474, minibatch 732/732, validation error 11.054795 %
# epoch 475, minibatch 732/732, validation error 11.054795 %
# epoch 476, minibatch 732/732, validation error 11.041096 %
#      epoch 476, minibatch 732/732, test error of best model 12.132018 %
# epoch 477, minibatch 732/732, validation error 11.041096 %
# epoch 478, minibatch 732/732, validation error 11.041096 %
# epoch 479, minibatch 732/732, validation error 11.013699 %
#      epoch 479, minibatch 732/732, test error of best model 12.110774 %
# epoch 480, minibatch 732/732, validation error 11.027397 %
# epoch 481, minibatch 732/732, validation error 11.027397 %
# epoch 482, minibatch 732/732, validation error 11.027397 %
# epoch 483, minibatch 732/732, validation error 11.041096 %
# epoch 484, minibatch 732/732, validation error 11.041096 %
# epoch 485, minibatch 732/732, validation error 11.027397 %
# Optimization complete. Best validation score of 11.013699 % obtained at iteration 350628, with test performance 12.110774 %
#
# The code for file hw2b.pyc ran for 9.63m
# The code for file hw2b.pyc ran for 33.03m
#
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 732/732, validation error 81.150685 %
#      epoch 1, minibatch 732/732, test error of best model 81.068285 %
# epoch 2, minibatch 732/732, validation error 81.123288 %
#      epoch 2, minibatch 732/732, test error of best model 81.094082 %
# epoch 3, minibatch 732/732, validation error 79.876712 %
#      epoch 3, minibatch 732/732, test error of best model 80.150228 %
# epoch 4, minibatch 732/732, validation error 73.013699 %
#      epoch 4, minibatch 732/732, test error of best model 72.506829 %
# epoch 5, minibatch 732/732, validation error 67.054795 %
#      epoch 5, minibatch 732/732, test error of best model 67.550835 %
# epoch 6, minibatch 732/732, validation error 63.013699 %
#      epoch 6, minibatch 732/732, test error of best model 62.946889 %
# epoch 7, minibatch 732/732, validation error 54.547945 %
#      epoch 7, minibatch 732/732, test error of best model 54.640364 %
# epoch 8, minibatch 732/732, validation error 50.616438 %
#      epoch 8, minibatch 732/732, test error of best model 51.144158 %
# epoch 9, minibatch 732/732, validation error 48.301370 %
#      epoch 9, minibatch 732/732, test error of best model 48.735964 %
# epoch 10, minibatch 732/732, validation error 45.383562 %
#      epoch 10, minibatch 732/732, test error of best model 45.789074 %
# epoch 11, minibatch 732/732, validation error 42.506849 %
#      epoch 11, minibatch 732/732, test error of best model 42.691958 %
# epoch 12, minibatch 732/732, validation error 40.301370 %
#      epoch 12, minibatch 732/732, test error of best model 40.361153 %
# epoch 13, minibatch 732/732, validation error 38.136986 %
#      epoch 13, minibatch 732/732, test error of best model 38.236722 %
# epoch 14, minibatch 732/732, validation error 36.246575 %
#      epoch 14, minibatch 732/732, test error of best model 36.505311 %
# epoch 15, minibatch 732/732, validation error 34.767123 %
#      epoch 15, minibatch 732/732, test error of best model 35.028832 %
# epoch 16, minibatch 732/732, validation error 33.219178 %
#      epoch 16, minibatch 732/732, test error of best model 33.810319 %
# epoch 17, minibatch 732/732, validation error 32.547945 %
#      epoch 17, minibatch 732/732, test error of best model 32.738998 %
# epoch 18, minibatch 732/732, validation error 31.575342 %
#      epoch 18, minibatch 732/732, test error of best model 31.846737 %
# epoch 19, minibatch 732/732, validation error 30.547945 %
#      epoch 19, minibatch 732/732, test error of best model 30.989378 %
# epoch 20, minibatch 732/732, validation error 29.767123 %
#      epoch 20, minibatch 732/732, test error of best model 30.106222 %
# epoch 21, minibatch 732/732, validation error 28.821918 %
#      epoch 21, minibatch 732/732, test error of best model 29.247344 %
# epoch 22, minibatch 732/732, validation error 28.000000 %
#      epoch 22, minibatch 732/732, test error of best model 28.470410 %
# epoch 23, minibatch 732/732, validation error 26.986301 %
#      epoch 23, minibatch 732/732, test error of best model 27.669196 %
# epoch 24, minibatch 732/732, validation error 26.328767 %
#      epoch 24, minibatch 732/732, test error of best model 26.916540 %
# epoch 25, minibatch 732/732, validation error 25.684932 %
#      epoch 25, minibatch 732/732, test error of best model 26.267071 %
# epoch 26, minibatch 732/732, validation error 25.041096 %
#      epoch 26, minibatch 732/732, test error of best model 25.684370 %
# epoch 27, minibatch 732/732, validation error 24.452055 %
#      epoch 27, minibatch 732/732, test error of best model 25.154780 %
# epoch 28, minibatch 732/732, validation error 24.205479 %
#      epoch 28, minibatch 732/732, test error of best model 24.672231 %
# epoch 29, minibatch 732/732, validation error 23.821918 %
#      epoch 29, minibatch 732/732, test error of best model 24.254932 %
# epoch 30, minibatch 732/732, validation error 23.438356 %
#      epoch 30, minibatch 732/732, test error of best model 23.778452 %
# epoch 31, minibatch 732/732, validation error 22.945205 %
#      epoch 31, minibatch 732/732, test error of best model 23.385432 %
# epoch 32, minibatch 732/732, validation error 22.465753 %
#      epoch 32, minibatch 732/732, test error of best model 22.992413 %
# epoch 33, minibatch 732/732, validation error 22.136986 %
#      epoch 33, minibatch 732/732, test error of best model 22.596358 %
# epoch 34, minibatch 732/732, validation error 21.684932 %
#      epoch 34, minibatch 732/732, test error of best model 22.189681 %
# epoch 35, minibatch 732/732, validation error 21.383562 %
#      epoch 35, minibatch 732/732, test error of best model 21.792109 %
# epoch 36, minibatch 732/732, validation error 20.931507 %
#      epoch 36, minibatch 732/732, test error of best model 21.440061 %
# epoch 37, minibatch 732/732, validation error 20.602740 %
#      epoch 37, minibatch 732/732, test error of best model 21.119879 %
# epoch 38, minibatch 732/732, validation error 20.246575 %
#      epoch 38, minibatch 732/732, test error of best model 20.866464 %
# epoch 39, minibatch 732/732, validation error 19.904110 %
#      epoch 39, minibatch 732/732, test error of best model 20.616085 %
# epoch 40, minibatch 732/732, validation error 19.575342 %
#      epoch 40, minibatch 732/732, test error of best model 20.336874 %
# epoch 41, minibatch 732/732, validation error 19.273973 %
#      epoch 41, minibatch 732/732, test error of best model 20.086495 %
# epoch 42, minibatch 732/732, validation error 19.000000 %
#      epoch 42, minibatch 732/732, test error of best model 19.843703 %
# epoch 43, minibatch 732/732, validation error 18.739726 %
#      epoch 43, minibatch 732/732, test error of best model 19.628225 %
# epoch 44, minibatch 732/732, validation error 18.452055 %
#      epoch 44, minibatch 732/732, test error of best model 19.380880 %
# epoch 45, minibatch 732/732, validation error 18.136986 %
#      epoch 45, minibatch 732/732, test error of best model 19.130501 %
# epoch 46, minibatch 732/732, validation error 17.849315 %
#      epoch 46, minibatch 732/732, test error of best model 18.913505 %
# epoch 47, minibatch 732/732, validation error 17.630137 %
#      epoch 47, minibatch 732/732, test error of best model 18.723824 %
# epoch 48, minibatch 732/732, validation error 17.438356 %
#      epoch 48, minibatch 732/732, test error of best model 18.541730 %
# epoch 49, minibatch 732/732, validation error 17.205479 %
#      epoch 49, minibatch 732/732, test error of best model 18.344461 %
# epoch 50, minibatch 732/732, validation error 17.000000 %
#      epoch 50, minibatch 732/732, test error of best model 18.163885 %
# epoch 51, minibatch 732/732, validation error 16.958904 %
#      epoch 51, minibatch 732/732, test error of best model 18.015175 %
# epoch 52, minibatch 732/732, validation error 16.835616 %
#      epoch 52, minibatch 732/732, test error of best model 17.846737 %
# epoch 53, minibatch 732/732, validation error 16.753425 %
#      epoch 53, minibatch 732/732, test error of best model 17.701062 %
# epoch 54, minibatch 732/732, validation error 16.671233 %
#      epoch 54, minibatch 732/732, test error of best model 17.564492 %
# epoch 55, minibatch 732/732, validation error 16.561644 %
#      epoch 55, minibatch 732/732, test error of best model 17.447648 %
# epoch 56, minibatch 732/732, validation error 16.493151 %
#      epoch 56, minibatch 732/732, test error of best model 17.291351 %
# epoch 57, minibatch 732/732, validation error 16.438356 %
#      epoch 57, minibatch 732/732, test error of best model 17.166920 %
# epoch 58, minibatch 732/732, validation error 16.328767 %
#      epoch 58, minibatch 732/732, test error of best model 17.066768 %
# epoch 59, minibatch 732/732, validation error 16.219178 %
#      epoch 59, minibatch 732/732, test error of best model 16.983308 %
# epoch 60, minibatch 732/732, validation error 16.109589 %
#      epoch 60, minibatch 732/732, test error of best model 16.863429 %
# epoch 61, minibatch 732/732, validation error 15.917808 %
#      epoch 61, minibatch 732/732, test error of best model 16.772382 %
# epoch 62, minibatch 732/732, validation error 15.780822 %
#      epoch 62, minibatch 732/732, test error of best model 16.672231 %
# epoch 63, minibatch 732/732, validation error 15.616438 %
#      epoch 63, minibatch 732/732, test error of best model 16.575114 %
# epoch 64, minibatch 732/732, validation error 15.520548 %
#      epoch 64, minibatch 732/732, test error of best model 16.512898 %
# epoch 65, minibatch 732/732, validation error 15.424658 %
#      epoch 65, minibatch 732/732, test error of best model 16.437026 %
# epoch 66, minibatch 732/732, validation error 15.328767 %
#      epoch 66, minibatch 732/732, test error of best model 16.341426 %
# epoch 67, minibatch 732/732, validation error 15.287671 %
#      epoch 67, minibatch 732/732, test error of best model 16.265554 %
# epoch 68, minibatch 732/732, validation error 15.287671 %
# epoch 69, minibatch 732/732, validation error 15.164384 %
#      epoch 69, minibatch 732/732, test error of best model 16.133536 %
# epoch 70, minibatch 732/732, validation error 15.136986 %
#      epoch 70, minibatch 732/732, test error of best model 16.078907 %
# epoch 71, minibatch 732/732, validation error 15.000000 %
#      epoch 71, minibatch 732/732, test error of best model 16.009105 %
# epoch 72, minibatch 732/732, validation error 14.931507 %
#      epoch 72, minibatch 732/732, test error of best model 15.952959 %
# epoch 73, minibatch 732/732, validation error 14.876712 %
#      epoch 73, minibatch 732/732, test error of best model 15.889226 %
# epoch 74, minibatch 732/732, validation error 14.849315 %
#      epoch 74, minibatch 732/732, test error of best model 15.823976 %
# epoch 75, minibatch 732/732, validation error 14.780822 %
#      epoch 75, minibatch 732/732, test error of best model 15.778452 %
# epoch 76, minibatch 732/732, validation error 14.739726 %
#      epoch 76, minibatch 732/732, test error of best model 15.714719 %
# epoch 77, minibatch 732/732, validation error 14.726027 %
#      epoch 77, minibatch 732/732, test error of best model 15.667678 %
# epoch 78, minibatch 732/732, validation error 14.698630 %
#      epoch 78, minibatch 732/732, test error of best model 15.617602 %
# epoch 79, minibatch 732/732, validation error 14.643836 %
#      epoch 79, minibatch 732/732, test error of best model 15.553869 %
# epoch 80, minibatch 732/732, validation error 14.643836 %
# epoch 81, minibatch 732/732, validation error 14.643836 %
# epoch 82, minibatch 732/732, validation error 14.547945 %
#      epoch 82, minibatch 732/732, test error of best model 15.396055 %
# epoch 83, minibatch 732/732, validation error 14.547945 %
# epoch 84, minibatch 732/732, validation error 14.479452 %
#      epoch 84, minibatch 732/732, test error of best model 15.301973 %
# epoch 85, minibatch 732/732, validation error 14.465753 %
#      epoch 85, minibatch 732/732, test error of best model 15.245827 %
# epoch 86, minibatch 732/732, validation error 14.342466 %
#      epoch 86, minibatch 732/732, test error of best model 15.185129 %
# epoch 87, minibatch 732/732, validation error 14.315068 %
#      epoch 87, minibatch 732/732, test error of best model 15.139605 %
# epoch 88, minibatch 732/732, validation error 14.246575 %
#      epoch 88, minibatch 732/732, test error of best model 15.083460 %
# epoch 89, minibatch 732/732, validation error 14.219178 %
#      epoch 89, minibatch 732/732, test error of best model 15.033384 %
# epoch 90, minibatch 732/732, validation error 14.246575 %
# epoch 91, minibatch 732/732, validation error 14.273973 %
# epoch 92, minibatch 732/732, validation error 14.232877 %
# epoch 93, minibatch 732/732, validation error 14.232877 %
# epoch 94, minibatch 732/732, validation error 14.219178 %
# epoch 95, minibatch 732/732, validation error 14.164384 %
#      epoch 95, minibatch 732/732, test error of best model 14.799697 %
# epoch 96, minibatch 732/732, validation error 14.123288 %
#      epoch 96, minibatch 732/732, test error of best model 14.776935 %
# epoch 97, minibatch 732/732, validation error 14.013699 %
#      epoch 97, minibatch 732/732, test error of best model 14.755690 %
# epoch 98, minibatch 732/732, validation error 13.986301 %
#      epoch 98, minibatch 732/732, test error of best model 14.707132 %
# epoch 99, minibatch 732/732, validation error 13.972603 %
#      epoch 99, minibatch 732/732, test error of best model 14.698027 %
# epoch 100, minibatch 732/732, validation error 13.904110 %
#      epoch 100, minibatch 732/732, test error of best model 14.670713 %
# epoch 101, minibatch 732/732, validation error 13.808219 %
#      epoch 101, minibatch 732/732, test error of best model 14.637329 %
# epoch 102, minibatch 732/732, validation error 13.780822 %
#      epoch 102, minibatch 732/732, test error of best model 14.600910 %
# epoch 103, minibatch 732/732, validation error 13.753425 %
#      epoch 103, minibatch 732/732, test error of best model 14.585736 %
# epoch 104, minibatch 732/732, validation error 13.780822 %
# epoch 105, minibatch 732/732, validation error 13.767123 %
# epoch 106, minibatch 732/732, validation error 13.767123 %
# epoch 107, minibatch 732/732, validation error 13.767123 %
# epoch 108, minibatch 732/732, validation error 13.835616 %
# epoch 109, minibatch 732/732, validation error 13.808219 %
# epoch 110, minibatch 732/732, validation error 13.821918 %
# epoch 111, minibatch 732/732, validation error 13.821918 %
# epoch 112, minibatch 732/732, validation error 13.808219 %
# epoch 113, minibatch 732/732, validation error 13.794521 %
# epoch 114, minibatch 732/732, validation error 13.794521 %
# epoch 115, minibatch 732/732, validation error 13.753425 %
# epoch 116, minibatch 732/732, validation error 13.698630 %
#      epoch 116, minibatch 732/732, test error of best model 14.227618 %
# epoch 117, minibatch 732/732, validation error 13.657534 %
#      epoch 117, minibatch 732/732, test error of best model 14.201821 %
# epoch 118, minibatch 732/732, validation error 13.671233 %
# epoch 119, minibatch 732/732, validation error 13.602740 %
#      epoch 119, minibatch 732/732, test error of best model 14.157815 %
# epoch 120, minibatch 732/732, validation error 13.657534 %
# epoch 121, minibatch 732/732, validation error 13.684932 %
# epoch 122, minibatch 732/732, validation error 13.671233 %
# epoch 123, minibatch 732/732, validation error 13.671233 %
# epoch 124, minibatch 732/732, validation error 13.630137 %
# epoch 125, minibatch 732/732, validation error 13.616438 %
# epoch 126, minibatch 732/732, validation error 13.575342 %
#      epoch 126, minibatch 732/732, test error of best model 14.012140 %
# epoch 127, minibatch 732/732, validation error 13.506849 %
#      epoch 127, minibatch 732/732, test error of best model 14.006070 %
# epoch 128, minibatch 732/732, validation error 13.479452 %
#      epoch 128, minibatch 732/732, test error of best model 13.974203 %
# epoch 129, minibatch 732/732, validation error 13.479452 %
#      epoch 129, minibatch 732/732, test error of best model 13.963581 %
# epoch 130, minibatch 732/732, validation error 13.465753 %
#      epoch 130, minibatch 732/732, test error of best model 13.959029 %
# epoch 131, minibatch 732/732, validation error 13.465753 %
#      epoch 131, minibatch 732/732, test error of best model 13.918058 %
# epoch 132, minibatch 732/732, validation error 13.438356 %
#      epoch 132, minibatch 732/732, test error of best model 13.915023 %
# epoch 133, minibatch 732/732, validation error 13.410959 %
#      epoch 133, minibatch 732/732, test error of best model 13.907436 %
# epoch 134, minibatch 732/732, validation error 13.301370 %
#      epoch 134, minibatch 732/732, test error of best model 13.893778 %
# epoch 135, minibatch 732/732, validation error 13.301370 %
# epoch 136, minibatch 732/732, validation error 13.287671 %
#      epoch 136, minibatch 732/732, test error of best model 13.848255 %
# epoch 137, minibatch 732/732, validation error 13.205479 %
#      epoch 137, minibatch 732/732, test error of best model 13.837633 %
# epoch 138, minibatch 732/732, validation error 13.123288 %
#      epoch 138, minibatch 732/732, test error of best model 13.827011 %
# epoch 139, minibatch 732/732, validation error 13.109589 %
#      epoch 139, minibatch 732/732, test error of best model 13.813354 %
# epoch 140, minibatch 732/732, validation error 13.095890 %
#      epoch 140, minibatch 732/732, test error of best model 13.802731 %
# epoch 141, minibatch 732/732, validation error 13.082192 %
#      epoch 141, minibatch 732/732, test error of best model 13.790592 %
# epoch 142, minibatch 732/732, validation error 13.068493 %
#      epoch 142, minibatch 732/732, test error of best model 13.787557 %
# epoch 143, minibatch 732/732, validation error 13.027397 %
#      epoch 143, minibatch 732/732, test error of best model 13.786039 %
# epoch 144, minibatch 732/732, validation error 13.013699 %
#      epoch 144, minibatch 732/732, test error of best model 13.775417 %
# epoch 145, minibatch 732/732, validation error 12.972603 %
#      epoch 145, minibatch 732/732, test error of best model 13.757208 %
# epoch 146, minibatch 732/732, validation error 12.958904 %
#      epoch 146, minibatch 732/732, test error of best model 13.725341 %
# epoch 147, minibatch 732/732, validation error 12.958904 %
# epoch 148, minibatch 732/732, validation error 12.972603 %
# epoch 149, minibatch 732/732, validation error 12.945205 %
#      epoch 149, minibatch 732/732, test error of best model 13.673748 %
# epoch 150, minibatch 732/732, validation error 12.931507 %
#      epoch 150, minibatch 732/732, test error of best model 13.661608 %
# epoch 151, minibatch 732/732, validation error 12.863014 %
#      epoch 151, minibatch 732/732, test error of best model 13.646434 %
# epoch 152, minibatch 732/732, validation error 12.808219 %
#      epoch 152, minibatch 732/732, test error of best model 13.643399 %
# epoch 153, minibatch 732/732, validation error 12.780822 %
#      epoch 153, minibatch 732/732, test error of best model 13.619120 %
# epoch 154, minibatch 732/732, validation error 12.780822 %
# epoch 155, minibatch 732/732, validation error 12.753425 %
#      epoch 155, minibatch 732/732, test error of best model 13.593323 %
# epoch 156, minibatch 732/732, validation error 12.712329 %
#      epoch 156, minibatch 732/732, test error of best model 13.590288 %
# epoch 157, minibatch 732/732, validation error 12.698630 %
#      epoch 157, minibatch 732/732, test error of best model 13.587253 %
# epoch 158, minibatch 732/732, validation error 12.698630 %
# epoch 159, minibatch 732/732, validation error 12.698630 %
# epoch 160, minibatch 732/732, validation error 12.602740 %
#      epoch 160, minibatch 732/732, test error of best model 13.561457 %
# epoch 161, minibatch 732/732, validation error 12.547945 %
#      epoch 161, minibatch 732/732, test error of best model 13.532625 %
# epoch 162, minibatch 732/732, validation error 12.547945 %
# epoch 163, minibatch 732/732, validation error 12.534247 %
#      epoch 163, minibatch 732/732, test error of best model 13.505311 %
# epoch 164, minibatch 732/732, validation error 12.465753 %
#      epoch 164, minibatch 732/732, test error of best model 13.493171 %
# epoch 165, minibatch 732/732, validation error 12.479452 %
# epoch 166, minibatch 732/732, validation error 12.438356 %
#      epoch 166, minibatch 732/732, test error of best model 13.455235 %
# epoch 167, minibatch 732/732, validation error 12.438356 %
# epoch 168, minibatch 732/732, validation error 12.452055 %
# epoch 169, minibatch 732/732, validation error 12.479452 %
# epoch 170, minibatch 732/732, validation error 12.465753 %
# epoch 171, minibatch 732/732, validation error 12.465753 %
# epoch 172, minibatch 732/732, validation error 12.452055 %
# epoch 173, minibatch 732/732, validation error 12.452055 %
# epoch 174, minibatch 732/732, validation error 12.438356 %
# epoch 175, minibatch 732/732, validation error 12.438356 %
# epoch 176, minibatch 732/732, validation error 12.438356 %
# epoch 177, minibatch 732/732, validation error 12.479452 %
# epoch 178, minibatch 732/732, validation error 12.465753 %
# epoch 179, minibatch 732/732, validation error 12.438356 %
# epoch 180, minibatch 732/732, validation error 12.438356 %
# epoch 181, minibatch 732/732, validation error 12.410959 %
#      epoch 181, minibatch 732/732, test error of best model 13.273141 %
# epoch 182, minibatch 732/732, validation error 12.356164 %
#      epoch 182, minibatch 732/732, test error of best model 13.259484 %
# epoch 183, minibatch 732/732, validation error 12.315068 %
#      epoch 183, minibatch 732/732, test error of best model 13.239757 %
# epoch 184, minibatch 732/732, validation error 12.287671 %
#      epoch 184, minibatch 732/732, test error of best model 13.221548 %
# epoch 185, minibatch 732/732, validation error 12.273973 %
#      epoch 185, minibatch 732/732, test error of best model 13.210926 %
# epoch 186, minibatch 732/732, validation error 12.219178 %
#      epoch 186, minibatch 732/732, test error of best model 13.204856 %
# epoch 187, minibatch 732/732, validation error 12.232877 %
# epoch 188, minibatch 732/732, validation error 12.219178 %
# epoch 189, minibatch 732/732, validation error 12.219178 %
# epoch 190, minibatch 732/732, validation error 12.191781 %
#      epoch 190, minibatch 732/732, test error of best model 13.163885 %
# epoch 191, minibatch 732/732, validation error 12.178082 %
#      epoch 191, minibatch 732/732, test error of best model 13.148710 %
# epoch 192, minibatch 732/732, validation error 12.150685 %
#      epoch 192, minibatch 732/732, test error of best model 13.133536 %
# epoch 193, minibatch 732/732, validation error 12.123288 %
#      epoch 193, minibatch 732/732, test error of best model 13.132018 %
# epoch 194, minibatch 732/732, validation error 12.109589 %
#      epoch 194, minibatch 732/732, test error of best model 13.113809 %
# epoch 195, minibatch 732/732, validation error 12.095890 %
#      epoch 195, minibatch 732/732, test error of best model 13.113809 %
# epoch 196, minibatch 732/732, validation error 12.041096 %
#      epoch 196, minibatch 732/732, test error of best model 13.094082 %
# epoch 197, minibatch 732/732, validation error 12.054795 %
# epoch 198, minibatch 732/732, validation error 12.041096 %
# epoch 199, minibatch 732/732, validation error 12.027397 %
#      epoch 199, minibatch 732/732, test error of best model 13.069803 %
# epoch 200, minibatch 732/732, validation error 12.000000 %
#      epoch 200, minibatch 732/732, test error of best model 13.057663 %
# epoch 201, minibatch 732/732, validation error 11.986301 %
#      epoch 201, minibatch 732/732, test error of best model 13.050076 %
# epoch 202, minibatch 732/732, validation error 12.013699 %
# epoch 203, minibatch 732/732, validation error 12.013699 %
# epoch 204, minibatch 732/732, validation error 11.958904 %
#      epoch 204, minibatch 732/732, test error of best model 13.021244 %
# epoch 205, minibatch 732/732, validation error 11.958904 %
#      epoch 205, minibatch 732/732, test error of best model 13.006070 %
# epoch 206, minibatch 732/732, validation error 11.931507 %
#      epoch 206, minibatch 732/732, test error of best model 12.995448 %
# epoch 207, minibatch 732/732, validation error 11.972603 %
# epoch 208, minibatch 732/732, validation error 11.958904 %
# epoch 209, minibatch 732/732, validation error 11.972603 %
# epoch 210, minibatch 732/732, validation error 11.958904 %
# epoch 211, minibatch 732/732, validation error 11.958904 %
# epoch 212, minibatch 732/732, validation error 11.945205 %
# epoch 213, minibatch 732/732, validation error 11.904110 %
#      epoch 213, minibatch 732/732, test error of best model 12.883156 %
# epoch 214, minibatch 732/732, validation error 11.904110 %
# epoch 215, minibatch 732/732, validation error 11.917808 %
# epoch 216, minibatch 732/732, validation error 11.931507 %
# epoch 217, minibatch 732/732, validation error 11.917808 %
# epoch 218, minibatch 732/732, validation error 11.917808 %
# epoch 219, minibatch 732/732, validation error 11.904110 %
# epoch 220, minibatch 732/732, validation error 11.945205 %
# epoch 221, minibatch 732/732, validation error 11.945205 %
# epoch 222, minibatch 732/732, validation error 11.958904 %
# epoch 223, minibatch 732/732, validation error 11.931507 %
# epoch 224, minibatch 732/732, validation error 11.904110 %
# epoch 225, minibatch 732/732, validation error 11.890411 %
#      epoch 225, minibatch 732/732, test error of best model 12.784522 %
# epoch 226, minibatch 732/732, validation error 11.890411 %
# epoch 227, minibatch 732/732, validation error 11.904110 %
# epoch 228, minibatch 732/732, validation error 11.904110 %
# epoch 229, minibatch 732/732, validation error 11.876712 %
#      epoch 229, minibatch 732/732, test error of best model 12.742033 %
# epoch 230, minibatch 732/732, validation error 11.863014 %
#      epoch 230, minibatch 732/732, test error of best model 12.726859 %
# epoch 231, minibatch 732/732, validation error 11.808219 %
#      epoch 231, minibatch 732/732, test error of best model 12.713202 %
# epoch 232, minibatch 732/732, validation error 11.808219 %
# epoch 233, minibatch 732/732, validation error 11.821918 %
# epoch 234, minibatch 732/732, validation error 11.794521 %
#      epoch 234, minibatch 732/732, test error of best model 12.701062 %
# epoch 235, minibatch 732/732, validation error 11.780822 %
#      epoch 235, minibatch 732/732, test error of best model 12.691958 %
# epoch 236, minibatch 732/732, validation error 11.767123 %
#      epoch 236, minibatch 732/732, test error of best model 12.682853 %
# epoch 237, minibatch 732/732, validation error 11.767123 %
# epoch 238, minibatch 732/732, validation error 11.753425 %
#      epoch 238, minibatch 732/732, test error of best model 12.664643 %
# epoch 239, minibatch 732/732, validation error 11.698630 %
#      epoch 239, minibatch 732/732, test error of best model 12.638847 %
# epoch 240, minibatch 732/732, validation error 11.684932 %
#      epoch 240, minibatch 732/732, test error of best model 12.632777 %
# epoch 241, minibatch 732/732, validation error 11.698630 %
# epoch 242, minibatch 732/732, validation error 11.698630 %
# epoch 243, minibatch 732/732, validation error 11.698630 %
# epoch 244, minibatch 732/732, validation error 11.698630 %
# epoch 245, minibatch 732/732, validation error 11.698630 %
# epoch 246, minibatch 732/732, validation error 11.684932 %
# epoch 247, minibatch 732/732, validation error 11.657534 %
#      epoch 247, minibatch 732/732, test error of best model 12.564492 %
# epoch 248, minibatch 732/732, validation error 11.657534 %
# epoch 249, minibatch 732/732, validation error 11.657534 %
# epoch 250, minibatch 732/732, validation error 11.684932 %
# epoch 251, minibatch 732/732, validation error 11.684932 %
# epoch 252, minibatch 732/732, validation error 11.698630 %
# epoch 253, minibatch 732/732, validation error 11.671233 %
# epoch 254, minibatch 732/732, validation error 11.684932 %
# epoch 255, minibatch 732/732, validation error 11.698630 %
# epoch 256, minibatch 732/732, validation error 11.698630 %
# epoch 257, minibatch 732/732, validation error 11.671233 %
# epoch 258, minibatch 732/732, validation error 11.643836 %
#      epoch 258, minibatch 732/732, test error of best model 12.468892 %
# epoch 259, minibatch 732/732, validation error 11.643836 %
# epoch 260, minibatch 732/732, validation error 11.630137 %
#      epoch 260, minibatch 732/732, test error of best model 12.467375 %
# epoch 261, minibatch 732/732, validation error 11.589041 %
#      epoch 261, minibatch 732/732, test error of best model 12.462822 %
# epoch 262, minibatch 732/732, validation error 11.616438 %
# epoch 263, minibatch 732/732, validation error 11.589041 %
# epoch 264, minibatch 732/732, validation error 11.575342 %
#      epoch 264, minibatch 732/732, test error of best model 12.429439 %
# epoch 265, minibatch 732/732, validation error 11.547945 %
#      epoch 265, minibatch 732/732, test error of best model 12.427921 %
# epoch 266, minibatch 732/732, validation error 11.561644 %
# epoch 267, minibatch 732/732, validation error 11.561644 %
# epoch 268, minibatch 732/732, validation error 11.534247 %
#      epoch 268, minibatch 732/732, test error of best model 12.405159 %
# epoch 269, minibatch 732/732, validation error 11.520548 %
#      epoch 269, minibatch 732/732, test error of best model 12.408194 %
# epoch 270, minibatch 732/732, validation error 11.506849 %
#      epoch 270, minibatch 732/732, test error of best model 12.400607 %
# epoch 271, minibatch 732/732, validation error 11.493151 %
#      epoch 271, minibatch 732/732, test error of best model 12.399090 %
# epoch 272, minibatch 732/732, validation error 11.479452 %
#      epoch 272, minibatch 732/732, test error of best model 12.396055 %
# epoch 273, minibatch 732/732, validation error 11.465753 %
#      epoch 273, minibatch 732/732, test error of best model 12.385432 %
# epoch 274, minibatch 732/732, validation error 11.438356 %
#      epoch 274, minibatch 732/732, test error of best model 12.382398 %
# epoch 275, minibatch 732/732, validation error 11.452055 %
# epoch 276, minibatch 732/732, validation error 11.424658 %
#      epoch 276, minibatch 732/732, test error of best model 12.352049 %
# epoch 277, minibatch 732/732, validation error 11.424658 %
# epoch 278, minibatch 732/732, validation error 11.410959 %
#      epoch 278, minibatch 732/732, test error of best model 12.335357 %
# epoch 279, minibatch 732/732, validation error 11.410959 %
# epoch 280, minibatch 732/732, validation error 11.369863 %
#      epoch 280, minibatch 732/732, test error of best model 12.323217 %
# epoch 281, minibatch 732/732, validation error 11.397260 %
# epoch 282, minibatch 732/732, validation error 11.397260 %
# epoch 283, minibatch 732/732, validation error 11.383562 %
# epoch 284, minibatch 732/732, validation error 11.369863 %
# epoch 285, minibatch 732/732, validation error 11.356164 %
#      epoch 285, minibatch 732/732, test error of best model 12.276176 %
# epoch 286, minibatch 732/732, validation error 11.356164 %
# epoch 287, minibatch 732/732, validation error 11.328767 %
#      epoch 287, minibatch 732/732, test error of best model 12.265554 %
# epoch 288, minibatch 732/732, validation error 11.328767 %
# epoch 289, minibatch 732/732, validation error 11.301370 %
#      epoch 289, minibatch 732/732, test error of best model 12.262519 %
# epoch 290, minibatch 732/732, validation error 11.287671 %
#      epoch 290, minibatch 732/732, test error of best model 12.261002 %
# epoch 291, minibatch 732/732, validation error 11.260274 %
#      epoch 291, minibatch 732/732, test error of best model 12.262519 %
# epoch 292, minibatch 732/732, validation error 11.260274 %
# epoch 293, minibatch 732/732, validation error 11.246575 %
#      epoch 293, minibatch 732/732, test error of best model 12.242792 %
# epoch 294, minibatch 732/732, validation error 11.232877 %
#      epoch 294, minibatch 732/732, test error of best model 12.229135 %
# epoch 295, minibatch 732/732, validation error 11.246575 %
# epoch 296, minibatch 732/732, validation error 11.246575 %
# epoch 297, minibatch 732/732, validation error 11.246575 %
# epoch 298, minibatch 732/732, validation error 11.219178 %
#      epoch 298, minibatch 732/732, test error of best model 12.229135 %
# epoch 299, minibatch 732/732, validation error 11.205479 %
#      epoch 299, minibatch 732/732, test error of best model 12.223065 %
# epoch 300, minibatch 732/732, validation error 11.219178 %
# epoch 301, minibatch 732/732, validation error 11.191781 %
#      epoch 301, minibatch 732/732, test error of best model 12.212443 %
# epoch 302, minibatch 732/732, validation error 11.191781 %
# epoch 303, minibatch 732/732, validation error 11.205479 %
# epoch 304, minibatch 732/732, validation error 11.191781 %
# epoch 305, minibatch 732/732, validation error 11.191781 %
# epoch 306, minibatch 732/732, validation error 11.205479 %
# epoch 307, minibatch 732/732, validation error 11.191781 %
# epoch 308, minibatch 732/732, validation error 11.191781 %
# epoch 309, minibatch 732/732, validation error 11.150685 %
#      epoch 309, minibatch 732/732, test error of best model 12.165402 %
# epoch 310, minibatch 732/732, validation error 11.150685 %
# epoch 311, minibatch 732/732, validation error 11.136986 %
#      epoch 311, minibatch 732/732, test error of best model 12.165402 %
# epoch 312, minibatch 732/732, validation error 11.123288 %
#      epoch 312, minibatch 732/732, test error of best model 12.157815 %
# epoch 313, minibatch 732/732, validation error 11.109589 %
#      epoch 313, minibatch 732/732, test error of best model 12.151745 %
# epoch 314, minibatch 732/732, validation error 11.123288 %
# epoch 315, minibatch 732/732, validation error 11.109589 %
# epoch 316, minibatch 732/732, validation error 11.136986 %
# epoch 317, minibatch 732/732, validation error 11.150685 %
# epoch 318, minibatch 732/732, validation error 11.150685 %
# epoch 319, minibatch 732/732, validation error 11.150685 %
# epoch 320, minibatch 732/732, validation error 11.178082 %
# epoch 321, minibatch 732/732, validation error 11.191781 %
# epoch 322, minibatch 732/732, validation error 11.178082 %
# epoch 323, minibatch 732/732, validation error 11.178082 %
# epoch 324, minibatch 732/732, validation error 11.191781 %
# epoch 325, minibatch 732/732, validation error 11.205479 %
# epoch 326, minibatch 732/732, validation error 11.205479 %
# epoch 327, minibatch 732/732, validation error 11.205479 %
# Optimization complete. Best validation score of 11.109589 % obtained at iteration 229116, with test performance 12.151745 %
#
# The code for file hw2b.pyc ran for 27.88m
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 732/732, validation error 81.150685 %
#      epoch 1, minibatch 732/732, test error of best model 81.068285 %
# epoch 2, minibatch 732/732, validation error 80.904110 %
#      epoch 2, minibatch 732/732, test error of best model 80.934750 %
# epoch 3, minibatch 732/732, validation error 77.684932 %
#      epoch 3, minibatch 732/732, test error of best model 77.603945 %
# epoch 4, minibatch 732/732, validation error 71.178082 %
#      epoch 4, minibatch 732/732, test error of best model 71.420334 %
# epoch 5, minibatch 732/732, validation error 63.232877 %
#      epoch 5, minibatch 732/732, test error of best model 63.482549 %
# epoch 6, minibatch 732/732, validation error 60.547945 %
#      epoch 6, minibatch 732/732, test error of best model 59.972686 %
# epoch 7, minibatch 732/732, validation error 54.890411 %
#      epoch 7, minibatch 732/732, test error of best model 54.754173 %
# epoch 8, minibatch 732/732, validation error 50.082192 %
#      epoch 8, minibatch 732/732, test error of best model 50.573596 %
# epoch 9, minibatch 732/732, validation error 44.972603 %
#      epoch 9, minibatch 732/732, test error of best model 45.068285 %
# epoch 10, minibatch 732/732, validation error 40.972603 %
#      epoch 10, minibatch 732/732, test error of best model 41.215478 %
# epoch 11, minibatch 732/732, validation error 38.109589 %
#      epoch 11, minibatch 732/732, test error of best model 38.559939 %
# epoch 12, minibatch 732/732, validation error 36.328767 %
#      epoch 12, minibatch 732/732, test error of best model 36.779970 %
# epoch 13, minibatch 732/732, validation error 35.260274 %
#      epoch 13, minibatch 732/732, test error of best model 35.588771 %
# epoch 14, minibatch 732/732, validation error 33.835616 %
#      epoch 14, minibatch 732/732, test error of best model 34.327769 %
# epoch 15, minibatch 732/732, validation error 32.506849 %
#      epoch 15, minibatch 732/732, test error of best model 32.995448 %
# epoch 16, minibatch 732/732, validation error 31.383562 %
#      epoch 16, minibatch 732/732, test error of best model 31.843703 %
# epoch 17, minibatch 732/732, validation error 30.191781 %
#      epoch 17, minibatch 732/732, test error of best model 30.634294 %
# epoch 18, minibatch 732/732, validation error 28.917808 %
#      epoch 18, minibatch 732/732, test error of best model 29.603945 %
# epoch 19, minibatch 732/732, validation error 27.904110 %
#      epoch 19, minibatch 732/732, test error of best model 28.468892 %
# epoch 20, minibatch 732/732, validation error 26.767123 %
#      epoch 20, minibatch 732/732, test error of best model 27.525038 %
# epoch 21, minibatch 732/732, validation error 25.931507 %
#      epoch 21, minibatch 732/732, test error of best model 26.641882 %
# epoch 22, minibatch 732/732, validation error 25.164384 %
#      epoch 22, minibatch 732/732, test error of best model 25.831563 %
# epoch 23, minibatch 732/732, validation error 24.520548 %
#      epoch 23, minibatch 732/732, test error of best model 25.177542 %
# epoch 24, minibatch 732/732, validation error 23.821918 %
#      epoch 24, minibatch 732/732, test error of best model 24.614568 %
# epoch 25, minibatch 732/732, validation error 23.260274 %
#      epoch 25, minibatch 732/732, test error of best model 24.154780 %
# epoch 26, minibatch 732/732, validation error 22.876712 %
#      epoch 26, minibatch 732/732, test error of best model 23.743551 %
# epoch 27, minibatch 732/732, validation error 22.410959 %
#      epoch 27, minibatch 732/732, test error of best model 23.277693 %
# epoch 28, minibatch 732/732, validation error 22.095890 %
#      epoch 28, minibatch 732/732, test error of best model 22.842185 %
# epoch 29, minibatch 732/732, validation error 21.739726 %
#      epoch 29, minibatch 732/732, test error of best model 22.382398 %
# epoch 30, minibatch 732/732, validation error 21.356164 %
#      epoch 30, minibatch 732/732, test error of best model 22.019727 %
# epoch 31, minibatch 732/732, validation error 20.835616 %
#      epoch 31, minibatch 732/732, test error of best model 21.664643 %
# epoch 32, minibatch 732/732, validation error 20.506849 %
#      epoch 32, minibatch 732/732, test error of best model 21.277693 %
# epoch 33, minibatch 732/732, validation error 20.082192 %
#      epoch 33, minibatch 732/732, test error of best model 20.968134 %
# epoch 34, minibatch 732/732, validation error 19.739726 %
#      epoch 34, minibatch 732/732, test error of best model 20.663126 %
# epoch 35, minibatch 732/732, validation error 19.397260 %
#      epoch 35, minibatch 732/732, test error of best model 20.403642 %
# epoch 36, minibatch 732/732, validation error 19.191781 %
#      epoch 36, minibatch 732/732, test error of best model 20.157815 %
# epoch 37, minibatch 732/732, validation error 18.849315 %
#      epoch 37, minibatch 732/732, test error of best model 19.905918 %
# epoch 38, minibatch 732/732, validation error 18.616438 %
#      epoch 38, minibatch 732/732, test error of best model 19.676783 %
# epoch 39, minibatch 732/732, validation error 18.397260 %
#      epoch 39, minibatch 732/732, test error of best model 19.438543 %
# epoch 40, minibatch 732/732, validation error 18.095890 %
#      epoch 40, minibatch 732/732, test error of best model 19.194234 %
# epoch 41, minibatch 732/732, validation error 17.945205 %
#      epoch 41, minibatch 732/732, test error of best model 19.057663 %
# epoch 42, minibatch 732/732, validation error 17.602740 %
#      epoch 42, minibatch 732/732, test error of best model 18.946889 %
# epoch 43, minibatch 732/732, validation error 17.369863 %
#      epoch 43, minibatch 732/732, test error of best model 18.702580 %
# epoch 44, minibatch 732/732, validation error 17.260274 %
#      epoch 44, minibatch 732/732, test error of best model 18.522003 %
# epoch 45, minibatch 732/732, validation error 17.095890 %
#      epoch 45, minibatch 732/732, test error of best model 18.389985 %
# epoch 46, minibatch 732/732, validation error 16.958904 %
#      epoch 46, minibatch 732/732, test error of best model 18.259484 %
# epoch 47, minibatch 732/732, validation error 16.904110 %
#      epoch 47, minibatch 732/732, test error of best model 18.128983 %
# epoch 48, minibatch 732/732, validation error 16.726027 %
#      epoch 48, minibatch 732/732, test error of best model 17.965099 %
# epoch 49, minibatch 732/732, validation error 16.602740 %
#      epoch 49, minibatch 732/732, test error of best model 17.811836 %
# epoch 50, minibatch 732/732, validation error 16.520548 %
#      epoch 50, minibatch 732/732, test error of best model 17.610015 %
# epoch 51, minibatch 732/732, validation error 16.287671 %
#      epoch 51, minibatch 732/732, test error of best model 17.471927 %
# epoch 52, minibatch 732/732, validation error 16.054795 %
#      epoch 52, minibatch 732/732, test error of best model 17.335357 %
# epoch 53, minibatch 732/732, validation error 16.041096 %
#      epoch 53, minibatch 732/732, test error of best model 17.232170 %
# epoch 54, minibatch 732/732, validation error 15.972603 %
#      epoch 54, minibatch 732/732, test error of best model 17.138088 %
# epoch 55, minibatch 732/732, validation error 15.876712 %
#      epoch 55, minibatch 732/732, test error of best model 17.039454 %
# epoch 56, minibatch 732/732, validation error 15.849315 %
#      epoch 56, minibatch 732/732, test error of best model 16.922610 %
# epoch 57, minibatch 732/732, validation error 15.712329 %
#      epoch 57, minibatch 732/732, test error of best model 16.848255 %
# epoch 58, minibatch 732/732, validation error 15.506849 %
#      epoch 58, minibatch 732/732, test error of best model 16.749621 %
# epoch 59, minibatch 732/732, validation error 15.424658 %
#      epoch 59, minibatch 732/732, test error of best model 16.650986 %
# epoch 60, minibatch 732/732, validation error 15.342466 %
#      epoch 60, minibatch 732/732, test error of best model 16.528073 %
# epoch 61, minibatch 732/732, validation error 15.136986 %
#      epoch 61, minibatch 732/732, test error of best model 16.405159 %
# epoch 62, minibatch 732/732, validation error 15.109589 %
#      epoch 62, minibatch 732/732, test error of best model 16.300455 %
# epoch 63, minibatch 732/732, validation error 15.041096 %
#      epoch 63, minibatch 732/732, test error of best model 16.236722 %
# epoch 64, minibatch 732/732, validation error 14.972603 %
#      epoch 64, minibatch 732/732, test error of best model 16.154780 %
# epoch 65, minibatch 732/732, validation error 14.821918 %
#      epoch 65, minibatch 732/732, test error of best model 16.057663 %
# epoch 66, minibatch 732/732, validation error 14.575342 %
#      epoch 66, minibatch 732/732, test error of best model 15.960546 %
# epoch 67, minibatch 732/732, validation error 14.493151 %
#      epoch 67, minibatch 732/732, test error of best model 15.845220 %
# epoch 68, minibatch 732/732, validation error 14.506849 %
# epoch 69, minibatch 732/732, validation error 14.452055 %
#      epoch 69, minibatch 732/732, test error of best model 15.655539 %
# epoch 70, minibatch 732/732, validation error 14.342466 %
#      epoch 70, minibatch 732/732, test error of best model 15.587253 %
# epoch 71, minibatch 732/732, validation error 14.342466 %
# epoch 72, minibatch 732/732, validation error 14.287671 %
#      epoch 72, minibatch 732/732, test error of best model 15.409712 %
# epoch 73, minibatch 732/732, validation error 14.164384 %
#      epoch 73, minibatch 732/732, test error of best model 15.356601 %
# epoch 74, minibatch 732/732, validation error 14.109589 %
#      epoch 74, minibatch 732/732, test error of best model 15.300455 %
# epoch 75, minibatch 732/732, validation error 13.917808 %
#      epoch 75, minibatch 732/732, test error of best model 15.200303 %
# epoch 76, minibatch 732/732, validation error 13.863014 %
#      epoch 76, minibatch 732/732, test error of best model 15.121396 %
# epoch 77, minibatch 732/732, validation error 13.780822 %
#      epoch 77, minibatch 732/732, test error of best model 15.045524 %
# epoch 78, minibatch 732/732, validation error 13.753425 %
#      epoch 78, minibatch 732/732, test error of best model 14.965099 %
# epoch 79, minibatch 732/732, validation error 13.684932 %
#      epoch 79, minibatch 732/732, test error of best model 14.895296 %
# epoch 80, minibatch 732/732, validation error 13.575342 %
#      epoch 80, minibatch 732/732, test error of best model 14.861912 %
# epoch 81, minibatch 732/732, validation error 13.575342 %
# epoch 82, minibatch 732/732, validation error 13.506849 %
#      epoch 82, minibatch 732/732, test error of best model 14.779970 %
# epoch 83, minibatch 732/732, validation error 13.506849 %
# epoch 84, minibatch 732/732, validation error 13.493151 %
#      epoch 84, minibatch 732/732, test error of best model 14.687405 %
# epoch 85, minibatch 732/732, validation error 13.465753 %
#      epoch 85, minibatch 732/732, test error of best model 14.617602 %
# epoch 86, minibatch 732/732, validation error 13.301370 %
#      epoch 86, minibatch 732/732, test error of best model 14.573596 %
# epoch 87, minibatch 732/732, validation error 13.191781 %
#      epoch 87, minibatch 732/732, test error of best model 14.534143 %
# epoch 88, minibatch 732/732, validation error 13.178082 %
#      epoch 88, minibatch 732/732, test error of best model 14.490137 %
# epoch 89, minibatch 732/732, validation error 13.178082 %
# epoch 90, minibatch 732/732, validation error 13.136986 %
#      epoch 90, minibatch 732/732, test error of best model 14.411229 %
# epoch 91, minibatch 732/732, validation error 13.082192 %
#      epoch 91, minibatch 732/732, test error of best model 14.370258 %
# epoch 92, minibatch 732/732, validation error 13.041096 %
#      epoch 92, minibatch 732/732, test error of best model 14.352049 %
# epoch 93, minibatch 732/732, validation error 12.986301 %
#      epoch 93, minibatch 732/732, test error of best model 14.305008 %
# epoch 94, minibatch 732/732, validation error 13.000000 %
# epoch 95, minibatch 732/732, validation error 12.945205 %
#      epoch 95, minibatch 732/732, test error of best model 14.251897 %
# epoch 96, minibatch 732/732, validation error 12.931507 %
#      epoch 96, minibatch 732/732, test error of best model 14.213961 %
# epoch 97, minibatch 732/732, validation error 12.917808 %
#      epoch 97, minibatch 732/732, test error of best model 14.180577 %
# epoch 98, minibatch 732/732, validation error 12.835616 %
#      epoch 98, minibatch 732/732, test error of best model 14.145675 %
# epoch 99, minibatch 732/732, validation error 12.739726 %
#      epoch 99, minibatch 732/732, test error of best model 14.095599 %
# epoch 100, minibatch 732/732, validation error 12.712329 %
#      epoch 100, minibatch 732/732, test error of best model 14.066768 %
# epoch 101, minibatch 732/732, validation error 12.657534 %
#      epoch 101, minibatch 732/732, test error of best model 14.040971 %
# epoch 102, minibatch 732/732, validation error 12.630137 %
#      epoch 102, minibatch 732/732, test error of best model 14.015175 %
# epoch 103, minibatch 732/732, validation error 12.630137 %
# epoch 104, minibatch 732/732, validation error 12.643836 %
# epoch 105, minibatch 732/732, validation error 12.602740 %
#      epoch 105, minibatch 732/732, test error of best model 13.919575 %
# epoch 106, minibatch 732/732, validation error 12.602740 %
# epoch 107, minibatch 732/732, validation error 12.602740 %
# epoch 108, minibatch 732/732, validation error 12.602740 %
# epoch 109, minibatch 732/732, validation error 12.561644 %
#      epoch 109, minibatch 732/732, test error of best model 13.807284 %
# epoch 110, minibatch 732/732, validation error 12.547945 %
#      epoch 110, minibatch 732/732, test error of best model 13.770865 %
# epoch 111, minibatch 732/732, validation error 12.547945 %
# epoch 112, minibatch 732/732, validation error 12.547945 %
# epoch 113, minibatch 732/732, validation error 12.520548 %
#      epoch 113, minibatch 732/732, test error of best model 13.719272 %
# epoch 114, minibatch 732/732, validation error 12.506849 %
#      epoch 114, minibatch 732/732, test error of best model 13.701062 %
# epoch 115, minibatch 732/732, validation error 12.397260 %
#      epoch 115, minibatch 732/732, test error of best model 13.681335 %
# epoch 116, minibatch 732/732, validation error 12.410959 %
# epoch 117, minibatch 732/732, validation error 12.328767 %
#      epoch 117, minibatch 732/732, test error of best model 13.654021 %
# epoch 118, minibatch 732/732, validation error 12.301370 %
#      epoch 118, minibatch 732/732, test error of best model 13.635812 %
# epoch 119, minibatch 732/732, validation error 12.342466 %
# epoch 120, minibatch 732/732, validation error 12.342466 %
# epoch 121, minibatch 732/732, validation error 12.356164 %
# epoch 122, minibatch 732/732, validation error 12.356164 %
# epoch 123, minibatch 732/732, validation error 12.369863 %
# epoch 124, minibatch 732/732, validation error 12.397260 %
# epoch 125, minibatch 732/732, validation error 12.479452 %
# epoch 126, minibatch 732/732, validation error 12.465753 %
# epoch 127, minibatch 732/732, validation error 12.465753 %
# epoch 128, minibatch 732/732, validation error 12.493151 %
# epoch 129, minibatch 732/732, validation error 12.493151 %
# epoch 130, minibatch 732/732, validation error 12.452055 %
# epoch 131, minibatch 732/732, validation error 12.424658 %
# epoch 132, minibatch 732/732, validation error 12.410959 %
# epoch 133, minibatch 732/732, validation error 12.410959 %
# epoch 134, minibatch 732/732, validation error 12.397260 %
# epoch 135, minibatch 732/732, validation error 12.383562 %
# epoch 136, minibatch 732/732, validation error 12.424658 %
# epoch 137, minibatch 732/732, validation error 12.424658 %
# epoch 138, minibatch 732/732, validation error 12.397260 %
# epoch 139, minibatch 732/732, validation error 12.383562 %
# epoch 140, minibatch 732/732, validation error 12.397260 %
# epoch 141, minibatch 732/732, validation error 12.356164 %
# epoch 142, minibatch 732/732, validation error 12.369863 %
# epoch 143, minibatch 732/732, validation error 12.383562 %
# epoch 144, minibatch 732/732, validation error 12.383562 %
# epoch 145, minibatch 732/732, validation error 12.369863 %
# epoch 146, minibatch 732/732, validation error 12.315068 %
# epoch 147, minibatch 732/732, validation error 12.287671 %
#      epoch 147, minibatch 732/732, test error of best model 13.370258 %
# epoch 148, minibatch 732/732, validation error 12.232877 %
#      epoch 148, minibatch 732/732, test error of best model 13.359636 %
# epoch 149, minibatch 732/732, validation error 12.219178 %
#      epoch 149, minibatch 732/732, test error of best model 13.364188 %
# epoch 150, minibatch 732/732, validation error 12.164384 %
#      epoch 150, minibatch 732/732, test error of best model 13.356601 %
# epoch 151, minibatch 732/732, validation error 12.178082 %
# epoch 152, minibatch 732/732, validation error 12.150685 %
#      epoch 152, minibatch 732/732, test error of best model 13.367223 %
# epoch 153, minibatch 732/732, validation error 12.123288 %
#      epoch 153, minibatch 732/732, test error of best model 13.347496 %
# epoch 154, minibatch 732/732, validation error 12.136986 %
# epoch 155, minibatch 732/732, validation error 12.109589 %
#      epoch 155, minibatch 732/732, test error of best model 13.356601 %
# epoch 156, minibatch 732/732, validation error 12.082192 %
#      epoch 156, minibatch 732/732, test error of best model 13.339909 %
# epoch 157, minibatch 732/732, validation error 12.054795 %
#      epoch 157, minibatch 732/732, test error of best model 13.335357 %
# epoch 158, minibatch 732/732, validation error 12.041096 %
#      epoch 158, minibatch 732/732, test error of best model 13.329287 %
# epoch 159, minibatch 732/732, validation error 12.054795 %
# epoch 160, minibatch 732/732, validation error 12.082192 %
# epoch 161, minibatch 732/732, validation error 12.082192 %
# epoch 162, minibatch 732/732, validation error 12.082192 %
# epoch 163, minibatch 732/732, validation error 12.082192 %
# epoch 164, minibatch 732/732, validation error 12.054795 %
# epoch 165, minibatch 732/732, validation error 12.082192 %
# epoch 166, minibatch 732/732, validation error 12.082192 %
# epoch 167, minibatch 732/732, validation error 12.082192 %
# epoch 168, minibatch 732/732, validation error 12.068493 %
# epoch 169, minibatch 732/732, validation error 12.027397 %
#      epoch 169, minibatch 732/732, test error of best model 13.259484 %
# epoch 170, minibatch 732/732, validation error 12.000000 %
#      epoch 170, minibatch 732/732, test error of best model 13.247344 %
# epoch 171, minibatch 732/732, validation error 11.986301 %
#      epoch 171, minibatch 732/732, test error of best model 13.242792 %
# epoch 172, minibatch 732/732, validation error 11.972603 %
#      epoch 172, minibatch 732/732, test error of best model 13.224583 %
# epoch 173, minibatch 732/732, validation error 11.972603 %
# epoch 174, minibatch 732/732, validation error 11.986301 %
# epoch 175, minibatch 732/732, validation error 12.000000 %
# epoch 176, minibatch 732/732, validation error 12.000000 %
# epoch 177, minibatch 732/732, validation error 11.986301 %
# epoch 178, minibatch 732/732, validation error 11.958904 %
#      epoch 178, minibatch 732/732, test error of best model 13.147193 %
# epoch 179, minibatch 732/732, validation error 11.904110 %
#      epoch 179, minibatch 732/732, test error of best model 13.138088 %
# epoch 180, minibatch 732/732, validation error 11.835616 %
#      epoch 180, minibatch 732/732, test error of best model 13.113809 %
# epoch 181, minibatch 732/732, validation error 11.849315 %
# epoch 182, minibatch 732/732, validation error 11.821918 %
#      epoch 182, minibatch 732/732, test error of best model 13.068285 %
# epoch 183, minibatch 732/732, validation error 11.794521 %
#      epoch 183, minibatch 732/732, test error of best model 13.062215 %
# epoch 184, minibatch 732/732, validation error 11.808219 %
# epoch 185, minibatch 732/732, validation error 11.753425 %
#      epoch 185, minibatch 732/732, test error of best model 13.025797 %
# epoch 186, minibatch 732/732, validation error 11.767123 %
# epoch 187, minibatch 732/732, validation error 11.726027 %
#      epoch 187, minibatch 732/732, test error of best model 12.965099 %
# epoch 188, minibatch 732/732, validation error 11.657534 %
#      epoch 188, minibatch 732/732, test error of best model 12.936267 %
# epoch 189, minibatch 732/732, validation error 11.602740 %
#      epoch 189, minibatch 732/732, test error of best model 12.927162 %
# epoch 190, minibatch 732/732, validation error 11.561644 %
#      epoch 190, minibatch 732/732, test error of best model 12.911988 %
# epoch 191, minibatch 732/732, validation error 11.547945 %
#      epoch 191, minibatch 732/732, test error of best model 12.892261 %
# epoch 192, minibatch 732/732, validation error 11.506849 %
#      epoch 192, minibatch 732/732, test error of best model 12.861912 %
# epoch 193, minibatch 732/732, validation error 11.520548 %
# epoch 194, minibatch 732/732, validation error 11.465753 %
#      epoch 194, minibatch 732/732, test error of best model 12.790592 %
# epoch 195, minibatch 732/732, validation error 11.465753 %
# epoch 196, minibatch 732/732, validation error 11.452055 %
#      epoch 196, minibatch 732/732, test error of best model 12.761760 %
# epoch 197, minibatch 732/732, validation error 11.438356 %
#      epoch 197, minibatch 732/732, test error of best model 12.732929 %
# epoch 198, minibatch 732/732, validation error 11.410959 %
#      epoch 198, minibatch 732/732, test error of best model 12.711684 %
# epoch 199, minibatch 732/732, validation error 11.410959 %
#      epoch 199, minibatch 732/732, test error of best model 12.693475 %
# epoch 200, minibatch 732/732, validation error 11.397260 %
#      epoch 200, minibatch 732/732, test error of best model 12.673748 %
# epoch 201, minibatch 732/732, validation error 11.342466 %
#      epoch 201, minibatch 732/732, test error of best model 12.641882 %
# epoch 202, minibatch 732/732, validation error 11.273973 %
#      epoch 202, minibatch 732/732, test error of best model 12.626707 %
# epoch 203, minibatch 732/732, validation error 11.301370 %
# epoch 204, minibatch 732/732, validation error 11.328767 %
# epoch 205, minibatch 732/732, validation error 11.328767 %
# epoch 206, minibatch 732/732, validation error 11.260274 %
#      epoch 206, minibatch 732/732, test error of best model 12.561457 %
# epoch 207, minibatch 732/732, validation error 11.246575 %
#      epoch 207, minibatch 732/732, test error of best model 12.546282 %
# epoch 208, minibatch 732/732, validation error 11.219178 %
#      epoch 208, minibatch 732/732, test error of best model 12.535660 %
# epoch 209, minibatch 732/732, validation error 11.191781 %
#      epoch 209, minibatch 732/732, test error of best model 12.525038 %
# epoch 210, minibatch 732/732, validation error 11.150685 %
#      epoch 210, minibatch 732/732, test error of best model 12.509863 %
# epoch 211, minibatch 732/732, validation error 11.150685 %
# epoch 212, minibatch 732/732, validation error 11.178082 %
# epoch 213, minibatch 732/732, validation error 11.164384 %
# epoch 214, minibatch 732/732, validation error 11.150685 %
# epoch 215, minibatch 732/732, validation error 11.150685 %
# epoch 216, minibatch 732/732, validation error 11.150685 %
# epoch 217, minibatch 732/732, validation error 11.082192 %
#      epoch 217, minibatch 732/732, test error of best model 12.385432 %
# epoch 218, minibatch 732/732, validation error 11.068493 %
#      epoch 218, minibatch 732/732, test error of best model 12.371775 %
# epoch 219, minibatch 732/732, validation error 10.958904 %
#      epoch 219, minibatch 732/732, test error of best model 12.365706 %
# epoch 220, minibatch 732/732, validation error 11.000000 %
# epoch 221, minibatch 732/732, validation error 10.972603 %
# epoch 222, minibatch 732/732, validation error 11.013699 %
# epoch 223, minibatch 732/732, validation error 10.986301 %
# epoch 224, minibatch 732/732, validation error 10.917808 %
#      epoch 224, minibatch 732/732, test error of best model 12.265554 %
# epoch 225, minibatch 732/732, validation error 10.917808 %
#      epoch 225, minibatch 732/732, test error of best model 12.245827 %
# epoch 226, minibatch 732/732, validation error 10.876712 %
#      epoch 226, minibatch 732/732, test error of best model 12.242792 %
# epoch 227, minibatch 732/732, validation error 10.863014 %
#      epoch 227, minibatch 732/732, test error of best model 12.233687 %
# epoch 228, minibatch 732/732, validation error 10.863014 %
#      epoch 228, minibatch 732/732, test error of best model 12.213961 %
# epoch 229, minibatch 732/732, validation error 10.821918 %
#      epoch 229, minibatch 732/732, test error of best model 12.195751 %
# epoch 230, minibatch 732/732, validation error 10.808219 %
#      epoch 230, minibatch 732/732, test error of best model 12.188164 %
# epoch 231, minibatch 732/732, validation error 10.753425 %
#      epoch 231, minibatch 732/732, test error of best model 12.174507 %
# epoch 232, minibatch 732/732, validation error 10.712329 %
#      epoch 232, minibatch 732/732, test error of best model 12.160850 %
# epoch 233, minibatch 732/732, validation error 10.726027 %
# epoch 234, minibatch 732/732, validation error 10.726027 %
# epoch 235, minibatch 732/732, validation error 10.753425 %
# epoch 236, minibatch 732/732, validation error 10.753425 %
# epoch 237, minibatch 732/732, validation error 10.767123 %
# epoch 238, minibatch 732/732, validation error 10.726027 %
# epoch 239, minibatch 732/732, validation error 10.739726 %
# epoch 240, minibatch 732/732, validation error 10.767123 %
# epoch 241, minibatch 732/732, validation error 10.712329 %
#      epoch 241, minibatch 732/732, test error of best model 12.071320 %
# epoch 242, minibatch 732/732, validation error 10.698630 %
#      epoch 242, minibatch 732/732, test error of best model 12.071320 %
# epoch 243, minibatch 732/732, validation error 10.671233 %
#      epoch 243, minibatch 732/732, test error of best model 12.060698 %
# epoch 244, minibatch 732/732, validation error 10.630137 %
#      epoch 244, minibatch 732/732, test error of best model 12.044006 %
# epoch 245, minibatch 732/732, validation error 10.657534 %
# epoch 246, minibatch 732/732, validation error 10.657534 %
# epoch 247, minibatch 732/732, validation error 10.643836 %
# epoch 248, minibatch 732/732, validation error 10.643836 %
# epoch 249, minibatch 732/732, validation error 10.630137 %
# epoch 250, minibatch 732/732, validation error 10.616438 %
#      epoch 250, minibatch 732/732, test error of best model 11.984825 %
# epoch 251, minibatch 732/732, validation error 10.575342 %
#      epoch 251, minibatch 732/732, test error of best model 11.983308 %
# epoch 252, minibatch 732/732, validation error 10.547945 %
#      epoch 252, minibatch 732/732, test error of best model 11.989378 %
# epoch 253, minibatch 732/732, validation error 10.547945 %
# epoch 254, minibatch 732/732, validation error 10.534247 %
#      epoch 254, minibatch 732/732, test error of best model 11.978756 %
# epoch 255, minibatch 732/732, validation error 10.520548 %
#      epoch 255, minibatch 732/732, test error of best model 11.975721 %
# epoch 256, minibatch 732/732, validation error 10.506849 %
#      epoch 256, minibatch 732/732, test error of best model 11.966616 %
# epoch 257, minibatch 732/732, validation error 10.493151 %
#      epoch 257, minibatch 732/732, test error of best model 11.960546 %
# epoch 258, minibatch 732/732, validation error 10.506849 %
# epoch 259, minibatch 732/732, validation error 10.506849 %
# epoch 260, minibatch 732/732, validation error 10.479452 %
#      epoch 260, minibatch 732/732, test error of best model 11.915023 %
# epoch 261, minibatch 732/732, validation error 10.479452 %
# epoch 262, minibatch 732/732, validation error 10.465753 %
#      epoch 262, minibatch 732/732, test error of best model 11.910470 %
# epoch 263, minibatch 732/732, validation error 10.438356 %
#      epoch 263, minibatch 732/732, test error of best model 11.892261 %
# epoch 264, minibatch 732/732, validation error 10.410959 %
#      epoch 264, minibatch 732/732, test error of best model 11.887709 %
# epoch 265, minibatch 732/732, validation error 10.397260 %
#      epoch 265, minibatch 732/732, test error of best model 11.895296 %
# epoch 266, minibatch 732/732, validation error 10.369863 %
#      epoch 266, minibatch 732/732, test error of best model 11.890744 %
# epoch 267, minibatch 732/732, validation error 10.383562 %
# epoch 268, minibatch 732/732, validation error 10.356164 %
#      epoch 268, minibatch 732/732, test error of best model 11.858877 %
# epoch 269, minibatch 732/732, validation error 10.356164 %
# epoch 270, minibatch 732/732, validation error 10.383562 %
# epoch 271, minibatch 732/732, validation error 10.410959 %
# epoch 272, minibatch 732/732, validation error 10.410959 %
# epoch 273, minibatch 732/732, validation error 10.369863 %
# epoch 274, minibatch 732/732, validation error 10.369863 %
# epoch 275, minibatch 732/732, validation error 10.369863 %
# epoch 276, minibatch 732/732, validation error 10.315068 %
#      epoch 276, minibatch 732/732, test error of best model 11.808801 %
# epoch 277, minibatch 732/732, validation error 10.301370 %
#      epoch 277, minibatch 732/732, test error of best model 11.799697 %
# epoch 278, minibatch 732/732, validation error 10.273973 %
#      epoch 278, minibatch 732/732, test error of best model 11.793627 %
# epoch 279, minibatch 732/732, validation error 10.260274 %
#      epoch 279, minibatch 732/732, test error of best model 11.787557 %
# epoch 280, minibatch 732/732, validation error 10.246575 %
#      epoch 280, minibatch 732/732, test error of best model 11.778452 %
# epoch 281, minibatch 732/732, validation error 10.246575 %
# epoch 282, minibatch 732/732, validation error 10.260274 %
# epoch 283, minibatch 732/732, validation error 10.260274 %
# epoch 284, minibatch 732/732, validation error 10.232877 %
#      epoch 284, minibatch 732/732, test error of best model 11.764795 %
# epoch 285, minibatch 732/732, validation error 10.178082 %
#      epoch 285, minibatch 732/732, test error of best model 11.757208 %
# epoch 286, minibatch 732/732, validation error 10.191781 %
# epoch 287, minibatch 732/732, validation error 10.205479 %
# epoch 288, minibatch 732/732, validation error 10.191781 %
# epoch 289, minibatch 732/732, validation error 10.191781 %
# epoch 290, minibatch 732/732, validation error 10.178082 %
# epoch 291, minibatch 732/732, validation error 10.164384 %
#      epoch 291, minibatch 732/732, test error of best model 11.763278 %
# epoch 292, minibatch 732/732, validation error 10.205479 %
# epoch 293, minibatch 732/732, validation error 10.178082 %
# epoch 294, minibatch 732/732, validation error 10.150685 %
#      epoch 294, minibatch 732/732, test error of best model 11.754173 %
# epoch 295, minibatch 732/732, validation error 10.164384 %
# epoch 296, minibatch 732/732, validation error 10.178082 %
# epoch 297, minibatch 732/732, validation error 10.191781 %
# epoch 298, minibatch 732/732, validation error 10.205479 %
# epoch 299, minibatch 732/732, validation error 10.232877 %
# epoch 300, minibatch 732/732, validation error 10.205479 %
# epoch 301, minibatch 732/732, validation error 10.191781 %
# epoch 302, minibatch 732/732, validation error 10.205479 %
# epoch 303, minibatch 732/732, validation error 10.191781 %
# epoch 304, minibatch 732/732, validation error 10.205479 %
# epoch 305, minibatch 732/732, validation error 10.205479 %
# epoch 306, minibatch 732/732, validation error 10.232877 %
# epoch 307, minibatch 732/732, validation error 10.219178 %
# epoch 308, minibatch 732/732, validation error 10.219178 %
# epoch 309, minibatch 732/732, validation error 10.178082 %
# epoch 310, minibatch 732/732, validation error 10.164384 %
# epoch 311, minibatch 732/732, validation error 10.178082 %
# epoch 312, minibatch 732/732, validation error 10.164384 %
# epoch 313, minibatch 732/732, validation error 10.191781 %
# epoch 314, minibatch 732/732, validation error 10.205479 %
# epoch 315, minibatch 732/732, validation error 10.219178 %
# epoch 316, minibatch 732/732, validation error 10.219178 %
# epoch 317, minibatch 732/732, validation error 10.232877 %
# epoch 318, minibatch 732/732, validation error 10.232877 %
# epoch 319, minibatch 732/732, validation error 10.273973 %
# epoch 320, minibatch 732/732, validation error 10.287671 %
# epoch 321, minibatch 732/732, validation error 10.273973 %
# epoch 322, minibatch 732/732, validation error 10.273973 %
# epoch 323, minibatch 732/732, validation error 10.301370 %
# epoch 324, minibatch 732/732, validation error 10.301370 %
# epoch 325, minibatch 732/732, validation error 10.287671 %
# epoch 326, minibatch 732/732, validation error 10.301370 %
# epoch 327, minibatch 732/732, validation error 10.287671 %
# epoch 328, minibatch 732/732, validation error 10.273973 %
# epoch 329, minibatch 732/732, validation error 10.273973 %
# epoch 330, minibatch 732/732, validation error 10.273973 %
# epoch 331, minibatch 732/732, validation error 10.273973 %
# epoch 332, minibatch 732/732, validation error 10.260274 %
# epoch 333, minibatch 732/732, validation error 10.273973 %
# epoch 334, minibatch 732/732, validation error 10.287671 %
# epoch 335, minibatch 732/732, validation error 10.273973 %
# epoch 336, minibatch 732/732, validation error 10.260274 %
# epoch 337, minibatch 732/732, validation error 10.273973 %
# epoch 338, minibatch 732/732, validation error 10.246575 %
# epoch 339, minibatch 732/732, validation error 10.219178 %
# epoch 340, minibatch 732/732, validation error 10.260274 %
# epoch 341, minibatch 732/732, validation error 10.260274 %
# epoch 342, minibatch 732/732, validation error 10.260274 %
# epoch 343, minibatch 732/732, validation error 10.260274 %
# epoch 344, minibatch 732/732, validation error 10.273973 %
# epoch 345, minibatch 732/732, validation error 10.219178 %
# epoch 346, minibatch 732/732, validation error 10.219178 %
# epoch 347, minibatch 732/732, validation error 10.205479 %
# epoch 348, minibatch 732/732, validation error 10.205479 %
# epoch 349, minibatch 732/732, validation error 10.205479 %
# epoch 350, minibatch 732/732, validation error 10.136986 %
#      epoch 350, minibatch 732/732, test error of best model 11.679818 %
# epoch 351, minibatch 732/732, validation error 10.150685 %
# epoch 352, minibatch 732/732, validation error 10.150685 %
# epoch 353, minibatch 732/732, validation error 10.150685 %
# epoch 354, minibatch 732/732, validation error 10.164384 %
# epoch 355, minibatch 732/732, validation error 10.164384 %
# epoch 356, minibatch 732/732, validation error 10.136986 %
# epoch 357, minibatch 732/732, validation error 10.095890 %
#      epoch 357, minibatch 732/732, test error of best model 11.646434 %
# epoch 358, minibatch 732/732, validation error 10.109589 %
# epoch 359, minibatch 732/732, validation error 10.082192 %
#      epoch 359, minibatch 732/732, test error of best model 11.632777 %
# epoch 360, minibatch 732/732, validation error 10.041096 %
#      epoch 360, minibatch 732/732, test error of best model 11.619120 %
# epoch 361, minibatch 732/732, validation error 10.013699 %
#      epoch 361, minibatch 732/732, test error of best model 11.622155 %
# epoch 362, minibatch 732/732, validation error 10.000000 %
#      epoch 362, minibatch 732/732, test error of best model 11.620637 %
# epoch 363, minibatch 732/732, validation error 10.013699 %
# epoch 364, minibatch 732/732, validation error 10.027397 %
# epoch 365, minibatch 732/732, validation error 10.000000 %
# epoch 366, minibatch 732/732, validation error 10.000000 %
# epoch 367, minibatch 732/732, validation error 10.013699 %
# epoch 368, minibatch 732/732, validation error 9.986301 %
#      epoch 368, minibatch 732/732, test error of best model 11.559939 %
# epoch 369, minibatch 732/732, validation error 9.958904 %
#      epoch 369, minibatch 732/732, test error of best model 11.543247 %
# epoch 370, minibatch 732/732, validation error 9.958904 %
# epoch 371, minibatch 732/732, validation error 9.972603 %
# epoch 372, minibatch 732/732, validation error 9.986301 %
# epoch 373, minibatch 732/732, validation error 9.945205 %
#      epoch 373, minibatch 732/732, test error of best model 11.506829 %
# epoch 374, minibatch 732/732, validation error 9.931507 %
#      epoch 374, minibatch 732/732, test error of best model 11.502276 %
# epoch 375, minibatch 732/732, validation error 9.931507 %
# epoch 376, minibatch 732/732, validation error 9.931507 %
# epoch 377, minibatch 732/732, validation error 9.890411 %
#      epoch 377, minibatch 732/732, test error of best model 11.496206 %
# epoch 378, minibatch 732/732, validation error 9.876712 %
#      epoch 378, minibatch 732/732, test error of best model 11.476480 %
# epoch 379, minibatch 732/732, validation error 9.876712 %
# epoch 380, minibatch 732/732, validation error 9.835616 %
#      epoch 380, minibatch 732/732, test error of best model 11.468892 %
# epoch 381, minibatch 732/732, validation error 9.821918 %
#      epoch 381, minibatch 732/732, test error of best model 11.473445 %
# epoch 382, minibatch 732/732, validation error 9.835616 %
# epoch 383, minibatch 732/732, validation error 9.835616 %
# epoch 384, minibatch 732/732, validation error 9.767123 %
#      epoch 384, minibatch 732/732, test error of best model 11.468892 %
# epoch 385, minibatch 732/732, validation error 9.753425 %
#      epoch 385, minibatch 732/732, test error of best model 11.462822 %
# epoch 386, minibatch 732/732, validation error 9.753425 %
# epoch 387, minibatch 732/732, validation error 9.767123 %
# epoch 388, minibatch 732/732, validation error 9.767123 %
# epoch 389, minibatch 732/732, validation error 9.780822 %
# epoch 390, minibatch 732/732, validation error 9.821918 %
# epoch 391, minibatch 732/732, validation error 9.821918 %
# epoch 392, minibatch 732/732, validation error 9.835616 %
# epoch 393, minibatch 732/732, validation error 9.835616 %
# epoch 394, minibatch 732/732, validation error 9.835616 %
# epoch 395, minibatch 732/732, validation error 9.863014 %
# epoch 396, minibatch 732/732, validation error 9.863014 %
# epoch 397, minibatch 732/732, validation error 9.821918 %
# epoch 398, minibatch 732/732, validation error 9.821918 %
# epoch 399, minibatch 732/732, validation error 9.808219 %
# epoch 400, minibatch 732/732, validation error 9.808219 %
# epoch 401, minibatch 732/732, validation error 9.821918 %
# epoch 402, minibatch 732/732, validation error 9.876712 %
# epoch 403, minibatch 732/732, validation error 9.876712 %
# epoch 404, minibatch 732/732, validation error 9.808219 %
# epoch 405, minibatch 732/732, validation error 9.794521 %
# epoch 406, minibatch 732/732, validation error 9.753425 %
# epoch 407, minibatch 732/732, validation error 9.863014 %
# epoch 408, minibatch 732/732, validation error 9.684932 %
#      epoch 408, minibatch 732/732, test error of best model 11.339909 %
# epoch 409, minibatch 732/732, validation error 10.013699 %
# epoch 410, minibatch 732/732, validation error 9.561644 %
#      epoch 410, minibatch 732/732, test error of best model 11.327769 %
# epoch 411, minibatch 732/732, validation error 10.205479 %
# epoch 412, minibatch 732/732, validation error 9.397260 %
#      epoch 412, minibatch 732/732, test error of best model 11.435508 %
# epoch 413, minibatch 732/732, validation error 10.191781 %
# epoch 414, minibatch 732/732, validation error 9.534247 %
# epoch 415, minibatch 732/732, validation error 10.205479 %
# epoch 416, minibatch 732/732, validation error 9.671233 %
# epoch 417, minibatch 732/732, validation error 10.136986 %
# epoch 418, minibatch 732/732, validation error 9.684932 %
# epoch 419, minibatch 732/732, validation error 10.109589 %
# epoch 420, minibatch 732/732, validation error 9.589041 %
# epoch 421, minibatch 732/732, validation error 9.986301 %
# epoch 422, minibatch 732/732, validation error 9.452055 %
# epoch 423, minibatch 732/732, validation error 9.931507 %
# epoch 424, minibatch 732/732, validation error 9.397260 %
# epoch 425, minibatch 732/732, validation error 10.013699 %
# epoch 426, minibatch 732/732, validation error 9.397260 %
# epoch 427, minibatch 732/732, validation error 10.068493 %
# epoch 428, minibatch 732/732, validation error 9.479452 %
# epoch 429, minibatch 732/732, validation error 10.054795 %
# epoch 430, minibatch 732/732, validation error 9.424658 %
# epoch 431, minibatch 732/732, validation error 10.054795 %
# epoch 432, minibatch 732/732, validation error 9.410959 %
# epoch 433, minibatch 732/732, validation error 10.041096 %
# epoch 434, minibatch 732/732, validation error 9.493151 %
# epoch 435, minibatch 732/732, validation error 10.013699 %
# epoch 436, minibatch 732/732, validation error 9.506849 %
# epoch 437, minibatch 732/732, validation error 10.000000 %
# epoch 438, minibatch 732/732, validation error 9.520548 %
# epoch 439, minibatch 732/732, validation error 9.931507 %
# epoch 440, minibatch 732/732, validation error 9.438356 %
# epoch 441, minibatch 732/732, validation error 9.904110 %
# epoch 442, minibatch 732/732, validation error 9.506849 %
# epoch 443, minibatch 732/732, validation error 9.890411 %
# epoch 444, minibatch 732/732, validation error 9.520548 %
# epoch 445, minibatch 732/732, validation error 9.890411 %
# epoch 446, minibatch 732/732, validation error 9.561644 %
# epoch 447, minibatch 732/732, validation error 9.876712 %
# epoch 448, minibatch 732/732, validation error 9.616438 %
# epoch 449, minibatch 732/732, validation error 9.890411 %
# epoch 450, minibatch 732/732, validation error 9.657534 %
# epoch 451, minibatch 732/732, validation error 9.835616 %
# epoch 452, minibatch 732/732, validation error 9.739726 %
# epoch 453, minibatch 732/732, validation error 9.821918 %
# epoch 454, minibatch 732/732, validation error 9.876712 %
# epoch 455, minibatch 732/732, validation error 9.739726 %
# epoch 456, minibatch 732/732, validation error 9.863014 %
# epoch 457, minibatch 732/732, validation error 9.835616 %
# epoch 458, minibatch 732/732, validation error 9.849315 %
# epoch 459, minibatch 732/732, validation error 9.904110 %
# epoch 460, minibatch 732/732, validation error 9.849315 %
# epoch 461, minibatch 732/732, validation error 9.890411 %
# epoch 462, minibatch 732/732, validation error 9.917808 %
# epoch 463, minibatch 732/732, validation error 9.767123 %
# epoch 464, minibatch 732/732, validation error 9.890411 %
# epoch 465, minibatch 732/732, validation error 9.821918 %
# epoch 466, minibatch 732/732, validation error 9.876712 %
# epoch 467, minibatch 732/732, validation error 9.849315 %
# epoch 468, minibatch 732/732, validation error 9.698630 %
# epoch 469, minibatch 732/732, validation error 9.712329 %
# epoch 470, minibatch 732/732, validation error 9.835616 %
# epoch 471, minibatch 732/732, validation error 9.890411 %
# epoch 472, minibatch 732/732, validation error 9.835616 %
# epoch 473, minibatch 732/732, validation error 9.986301 %
# epoch 474, minibatch 732/732, validation error 9.863014 %
# epoch 475, minibatch 732/732, validation error 9.917808 %
# epoch 476, minibatch 732/732, validation error 9.917808 %
# epoch 477, minibatch 732/732, validation error 10.109589 %
# epoch 478, minibatch 732/732, validation error 10.095890 %
# epoch 479, minibatch 732/732, validation error 10.095890 %
# epoch 480, minibatch 732/732, validation error 10.027397 %
# epoch 481, minibatch 732/732, validation error 10.013699 %
# epoch 482, minibatch 732/732, validation error 9.808219 %
# epoch 483, minibatch 732/732, validation error 9.863014 %
# epoch 484, minibatch 732/732, validation error 9.890411 %
# epoch 485, minibatch 732/732, validation error 9.794521 %
# epoch 486, minibatch 732/732, validation error 10.136986 %
# epoch 487, minibatch 732/732, validation error 9.931507 %
# epoch 488, minibatch 732/732, validation error 9.835616 %
# epoch 489, minibatch 732/732, validation error 10.027397 %
# epoch 490, minibatch 732/732, validation error 10.232877 %
# epoch 491, minibatch 732/732, validation error 10.068493 %
# epoch 492, minibatch 732/732, validation error 10.246575 %
# epoch 493, minibatch 732/732, validation error 9.972603 %
# epoch 494, minibatch 732/732, validation error 9.986301 %
# epoch 495, minibatch 732/732, validation error 9.986301 %
# epoch 496, minibatch 732/732, validation error 10.205479 %
# epoch 497, minibatch 732/732, validation error 10.041096 %
# epoch 498, minibatch 732/732, validation error 9.972603 %
# epoch 499, minibatch 732/732, validation error 10.123288 %
# epoch 500, minibatch 732/732, validation error 9.808219 %
# Optimization complete. Best validation score of 9.397260 % obtained at iteration 301584, with test performance 11.435508 %
#
# The code for file hw2b.pyc ran for 51.17m

# %% [markdown]
# Plot the result (reproducing Figure 1)

# %%
test_performance_bullet3 = [100 - round(100 * item, 2) for item in test_performance_bullet3]
x = list(range(1, 9, 2))
fig = plt.figure()
axes = fig.add_subplot(111)
axes.plot(x, test_performance_bullet3)
plt.xlim([0, 8])
plt.xlabel('Number of Hidden Layers')
plt.ylabel('Test Accuracy, [%]')
plt.show()

# %% [markdown]
# Document the choice of parameters, and discuss what you discover.

# %% [markdown]
# 1. Increase the L2 regulariser to 0.001 comparing to the default 0.0001. It would increase the cost and then shrink the coefficients.
#
# 2. According to the bullet 2 result, set activation function as tanh, increase the batch_size to 100, which would fasten the training process
#
# 3. The other parameters are: n_hidden=300, L1_reg=0.00, learning_rate=0.01, n_epochs=500, n_hidden_layer=[1, 3, 5, 7]
#
# 4. According to the plot above, increasing the number of hidden layers would increase the test rate.

# %% [markdown]
# ### Problem b: Bullet 4: Experiment with the number of hidden layers, but fix the total number of neurons

# %%
# The number of hidden layers: range(1, 7)
test_performance_bullet4 = []
for i in range(1, 7):
    temp_model = test_mlp(activation_function='tanh', batch_size=100, n_hidden=int(840/i), n_hidden_layer=i, L1_reg=0.00, 
                          L2_reg=0.001, learning_rate=0.01, n_epochs=500, verbose=True)
    test_performance_bullet4.append(temp_model)
# Out:
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 732/732, validation error 80.671233 %
#      epoch 1, minibatch 732/732, test error of best model 80.657056 %
# epoch 2, minibatch 732/732, validation error 79.205479 %
#      epoch 2, minibatch 732/732, test error of best model 79.393020 %
# epoch 3, minibatch 732/732, validation error 78.123288 %
#      epoch 3, minibatch 732/732, test error of best model 78.153263 %
# epoch 4, minibatch 732/732, validation error 76.945205 %
#      epoch 4, minibatch 732/732, test error of best model 76.866464 %
# epoch 5, minibatch 732/732, validation error 75.452055 %
#      epoch 5, minibatch 732/732, test error of best model 75.488619 %
# epoch 6, minibatch 732/732, validation error 74.178082 %
#      epoch 6, minibatch 732/732, test error of best model 73.783005 %
# epoch 7, minibatch 732/732, validation error 72.397260 %
#      epoch 7, minibatch 732/732, test error of best model 71.945372 %
# ...

# %% [markdown]
# Plot the result (reproducing Figure 2)

# %%
plt_test_performance_bullet4 = [100 - round(100 * item, 2) for item in test_performance_bullet4]
x = list(range(1, 7))
fig = plt.figure()
axes = fig.add_subplot(111)
axes.plot(x, plt_test_performance_bullet4)
plt.xlim([0, 8])
plt.xlabel('Number of Hidden Layers')
plt.ylabel('Test, Accuracy in %')
plt.show()

# %% [markdown]
# Document the choice of parameters, and discuss what you discover.

# %% [markdown]
# 1. Parameters: n_hidden_layer=[1, 2, 3, 4, 5, 6], n_hidden=840 / n_hidden_layer, L1_reg=0.00, L2_reg=0.001, learning_rate=0.01, n_epochs=500, activation_function='tanh', batch_size=100
# 2. Results: When fixed the number of neurons, increasing the number of layers would fisrt increase the accuracy but then would decrease the accuracy.

# %% [markdown]
# ### Problem b: Bullet 5: Experiment with the number of neurons in hidden layers, but fix the number of hidden layers

# %%
test_performance_bullet5 = []
for i in [100, 300, 500, 800, 1500]:
    temp_model = test_mlp(activation_function='tanh', batch_size=100, n_hidden=i, n_hidden_layer=1, L1_reg=0.00, 
                          L2_reg=0.001, learning_rate=0.01, n_epochs=500, verbose=True)
    test_performance_bullet5.append(temp_model)
# Out:
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 732/732, validation error 81.150685 %
#      epoch 1, minibatch 732/732, test error of best model 81.068285 %
# epoch 2, minibatch 732/732, validation error 81.150685 %
# epoch 3, minibatch 732/732, validation error 81.000000 %
#      epoch 3, minibatch 732/732, test error of best model 80.955994 %
# epoch 4, minibatch 732/732, validation error 80.424658 %
#      epoch 4, minibatch 732/732, test error of best model 80.552352 %
# epoch 5, minibatch 732/732, validation error 79.547945 %
#      epoch 5, minibatch 732/732, test error of best model 79.816388 %
# epoch 6, minibatch 732/732, validation error 78.041096 %
#      epoch 6, minibatch 732/732, test error of best model 78.024279 %
# epoch 7, minibatch 732/732, validation error 75.095890 %
#      epoch 7, minibatch 732/732, test error of best model 75.057663 %
# epoch 8, minibatch 732/732, validation error 71.712329 %
# ...

# %% [markdown]
# Plot the result (reproducing Figure 3)

# %%
test_performance_bullet5 = [100 - round(100 * item, 2) for item in test_performance_bullet5]
x = [100, 300, 500, 800, 1500]
fig = plt.figure()
axes = fig.add_subplot(111)
axes.plot(x, test_performance_bullet5)
plt.xlim([0, 1600])
plt.xlabel('Number of Neurons')
plt.ylabel('Test, Accuracy in %')
plt.show()

# %% [markdown]
# Document the choice of parameters, and discuss what you discover.

# %% [markdown]
# 1. Parameters: n_hidden = [100, 300, 500, 800, 1500], n_hidden_layer=1, L1_reg=0.00, L2_reg=0.001, learning_rate=0.01, n_epochs=500, activation_function='tanh', batch_size=100
# 2. Results: Increasing the number of neurons would fisrt increase the accuracy but then would decrease the accuracy.

# %% [markdown]
# ### Problem c: Bullet 1: Implement MLP(with dropout) with the parameters specified

# %%
import numpy as np
import matplotlib.pyplot as plt
import theano
import theano.tensor as T
from hw2c import load_data, LogisticRegression, DropoutHiddenLayer, test_mlp_dropout
# Out:
# Using gpu device 0: GRID K520 (CNMeM is disabled, cuDNN Version is too old. Update to v5, was 3007.)

# %%
test_mlp_dropout(learning_rate=0.01, L1_reg=0, L2_reg=0.0001, n_epochs=500,
                 batch_size=20, n_hidden=500, verbose=True, hidlayers=None, acttest=T.tanh, p=0.7)
# Out:
# ...
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 3296/3296, validation error 81.161202 %
#      epoch 1, minibatch 3296/3296, test error of best model 80.418909 %
# epoch 2, minibatch 3296/3296, validation error 81.051913 %
#      epoch 2, minibatch 3296/3296, test error of best model 80.368947 %
# epoch 3, minibatch 3296/3296, validation error 80.765027 %
#      epoch 3, minibatch 3296/3296, test error of best model 79.992314 %
# epoch 4, minibatch 3296/3296, validation error 76.024590 %
#      epoch 4, minibatch 3296/3296, test error of best model 75.215219 %
# epoch 5, minibatch 3296/3296, validation error 62.855191 %
#      epoch 5, minibatch 3296/3296, test error of best model 64.215988 %
# epoch 6, minibatch 3296/3296, validation error 56.092896 %
#      epoch 6, minibatch 3296/3296, test error of best model 57.386626 %
# epoch 7, minibatch 3296/3296, validation error 50.519126 %
# ...

# %% [markdown]
# ### Problem c: Bullet 2: Implement MLP(without dropout) with the parameters specified

# %%
test_mlp_dropout(learning_rate=0.01, L1_reg=0, L2_reg=0.0001, n_epochs=500,
                 batch_size=20, n_hidden=500, verbose=True, hidlayers=None, acttest=T.tanh, p=1)
# Out:
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 3296/3296, validation error 81.106557 %
#      epoch 1, minibatch 3296/3296, test error of best model 80.330515 %
# epoch 2, minibatch 3296/3296, validation error 73.032787 %
#      epoch 2, minibatch 3296/3296, test error of best model 72.498078 %
# epoch 3, minibatch 3296/3296, validation error 56.953552 %
#      epoch 3, minibatch 3296/3296, test error of best model 57.978478 %
# epoch 4, minibatch 3296/3296, validation error 46.079235 %
#      epoch 4, minibatch 3296/3296, test error of best model 47.413528 %
# epoch 5, minibatch 3296/3296, validation error 40.751366 %
#      epoch 5, minibatch 3296/3296, test error of best model 42.255957 %
# epoch 6, minibatch 3296/3296, validation error 36.243169 %
#      epoch 6, minibatch 3296/3296, test error of best model 38.378171 %
# epoch 7, minibatch 3296/3296, validation error 33.251366 %
# ...

# %% [markdown]
# ### Problem c: Bullet 2: Compare the two cases

# %% [markdown]
# 1. Parameters: n_hidden_layer=2, n_hidden=500, learning_rate=0.01, L1_reg=0, L2_reg=0.0001, n_epochs=500, batch_size=20, if use dropout, p=0.7
# 2. Result: Implementing MLP with dropout takes 3 hours while implementing MLP without dropout only needs 43 minutes. The accuracy for MLP with dropout is 85.27% while the accuracy for MLP without dropout is 80.71%. Using dropout could increase the accuracy.
