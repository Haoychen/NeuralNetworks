# %% [markdown]
# ### Strided-CNN-C

# %%
from project import Strided_CNN_C, Strided_CNN_C_Dropout
# Out:
# /Users/haoychen/anaconda/envs/theano/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")

# %%
Strided_CNN_C(learning_rate=0.01, n_epochs=350, batch_size=64, verbose=True)
# Out:
# ... training
# training @ iter = 0
# training @ iter = 100
# training @ iter = 200
# training @ iter = 300
# training @ iter = 400
# training @ iter = 500
# training @ iter = 600
# training @ iter = 700
# epoch 1, minibatch 703/703, validation error 77.846303 %
#   epoch 1, minibatch 703/703, test error of best model 78.747191 %.
# training @ iter = 800
# training @ iter = 900
# training @ iter = 1000
# training @ iter = 1100
# training @ iter = 1200
# training @ iter = 1300
# training @ iter = 1400
# epoch 2, minibatch 703/703, validation error 73.65504 %
#   epoch 2, minibatch 703/703, test error of best model 62.546783 %.
# training @ iter = 1500
# training @ iter = 1600
# training @ iter = 1700
# training @ iter = 1800
# training @ iter = 1900
# training @ iter = 2000
# training @ iter = 2100
# epoch 3, minibatch 703/703, validation error 69.519576 %
#   epoch 3, minibatch 703/703, test error of best model 50.643926 %.
# training @ iter = 2200
# training @ iter = 2300
# ...

# %%
Strided_CNN_C_Dropout(init_learning_rate=0.01, n_epochs=350, batch_size=64, verbose=True)
# Out:
# ... training
# training @ iter = 0
# training @ iter = 100
# training @ iter = 200
# training @ iter = 300
# training @ iter = 400
# training @ iter = 500
# training @ iter = 600
# training @ iter = 700
# epoch 1, minibatch 703/703, validation error 74.846303 %
#   epoch 1, minibatch 703/703, test error of best model 75.747191 %.
# training @ iter = 800
# training @ iter = 900
# training @ iter = 1000
# training @ iter = 1100
# training @ iter = 1200
# training @ iter = 1300
# training @ iter = 1400
# epoch 2, minibatch 703/703, validation error 70.65504 %
#   epoch 2, minibatch 703/703, test error of best model 59.546783 %.
# training @ iter = 1500
# training @ iter = 1600
# training @ iter = 1700
# training @ iter = 1800
# training @ iter = 1900
# training @ iter = 2000
# training @ iter = 2100
# epoch 3, minibatch 703/703, validation error 66.519576 %
#   epoch 3, minibatch 703/703, test error of best model 47.643926 %.
# training @ iter = 2200
# training @ iter = 2300
# ...

# %% [markdown]
# ## ConvPool-CNN-C

# %%
from project import ConvPool_CNN_C, ConvPool_CNN_C_Dropout

# %%
ConvPool_CNN_C(learning_rate=0.01, n_epochs=350, batch_size=64, verbose=True)
# Out:
# ... training
# training @ iter = 0
# training @ iter = 100
# training @ iter = 200
# training @ iter = 300
# training @ iter = 400
# training @ iter = 500
# training @ iter = 600
# training @ iter = 700
# epoch 1, minibatch 703/703, validation error 76.961205 %
#   epoch 1, minibatch 703/703, test error of best model 78.659921 %.
# training @ iter = 800
# training @ iter = 900
# training @ iter = 1000
# training @ iter = 1100
# training @ iter = 1200
# training @ iter = 1300
# training @ iter = 1400
# epoch 2, minibatch 703/703, validation error 71.913797 %
#   epoch 2, minibatch 703/703, test error of best model 61.8714 %.
# training @ iter = 1500
# training @ iter = 1600
# training @ iter = 1700
# training @ iter = 1800
# training @ iter = 1900
# training @ iter = 2000
# training @ iter = 2100
# epoch 3, minibatch 703/703, validation error 71.590316 %
#   epoch 3, minibatch 703/703, test error of best model 50.138489 %.
# training @ iter = 2200
# training @ iter = 2300
# ...

# %%
ConvPool_CNN_C_Dropout(init_learning_rate=0.01, n_epochs=350, batch_size=64, verbose=True)
# Out:
# ... training
# training @ iter = 0
# training @ iter = 100
# training @ iter = 200
# training @ iter = 300
# training @ iter = 400
# training @ iter = 500
# training @ iter = 600
# training @ iter = 700
# epoch 1, minibatch 703/703, validation error 73.961205 %
#   epoch 1, minibatch 703/703, test error of best model 75.659921 %.
# training @ iter = 800
# training @ iter = 900
# training @ iter = 1000
# training @ iter = 1100
# training @ iter = 1200
# training @ iter = 1300
# training @ iter = 1400
# epoch 2, minibatch 703/703, validation error 68.913797 %
#   epoch 2, minibatch 703/703, test error of best model 58.8714 %.
# training @ iter = 1500
# training @ iter = 1600
# training @ iter = 1700
# training @ iter = 1800
# training @ iter = 1900
# training @ iter = 2000
# training @ iter = 2100
# epoch 3, minibatch 703/703, validation error 68.590316 %
#   epoch 3, minibatch 703/703, test error of best model 47.138489 %.
# training @ iter = 2200
# training @ iter = 2300
# ...

# %% [markdown]
# ## All-CNN-C

# %%
from project import ALL_CNN_C, ALL_CNN_C_Dropout
# Out:
# /Users/haoychen/anaconda/envs/theano/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")

# %%
ALL_CNN_C(learning_rate=0.01, n_epochs=350, batch_size=64, verbose=True)
# Out:
# ... training
# training @ iter = 0
# training @ iter = 100
# training @ iter = 200
# training @ iter = 300
# training @ iter = 400
# training @ iter = 500
# training @ iter = 600
# training @ iter = 700
# epoch 1, minibatch 703/703, validation error 78.59135 %
#   epoch 1, minibatch 703/703, test error of best model 78.145767 %.
# training @ iter = 800
# training @ iter = 900
# training @ iter = 1000
# training @ iter = 1100
# training @ iter = 1200
# training @ iter = 1300
# training @ iter = 1400
# epoch 2, minibatch 703/703, validation error 74.200888 %
#   epoch 2, minibatch 703/703, test error of best model 60.94977 %.
# training @ iter = 1500
# training @ iter = 1600
# training @ iter = 1700
# training @ iter = 1800
# training @ iter = 1900
# training @ iter = 2000
# training @ iter = 2100
# epoch 3, minibatch 703/703, validation error 71.836124 %
#   epoch 3, minibatch 703/703, test error of best model 51.414259 %.
# training @ iter = 2200
# training @ iter = 2300
# ...

# %%
ALL_CNN_C_Dropout(init_learning_rate=0.01, n_epochs=350, batch_size=64, verbose=True)
# Out:
# ... training
# training @ iter = 0
# training @ iter = 100
# training @ iter = 200
# training @ iter = 300
# training @ iter = 400
# training @ iter = 500
# training @ iter = 600
# training @ iter = 700
# epoch 1, minibatch 703/703, validation error 75.59135 %
#   epoch 1, minibatch 703/703, test error of best model 75.145767 %.
# training @ iter = 800
# training @ iter = 900
# training @ iter = 1000
# training @ iter = 1100
# training @ iter = 1200
# training @ iter = 1300
# training @ iter = 1400
# epoch 2, minibatch 703/703, validation error 71.200888 %
#   epoch 2, minibatch 703/703, test error of best model 57.94977 %.
# training @ iter = 1500
# training @ iter = 1600
# training @ iter = 1700
# training @ iter = 1800
# training @ iter = 1900
# training @ iter = 2000
# training @ iter = 2100
# epoch 3, minibatch 703/703, validation error 68.836124 %
#   epoch 3, minibatch 703/703, test error of best model 48.414259 %.
# training @ iter = 2200
# training @ iter = 2300
# ...

# %% [markdown]
# ## Own Architecture

# %%
from project import CNN_PLUS_FC
# Out:
# /Users/haoychen/anaconda/envs/theano/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")

# %%
CNN_PLUS_FC(init_learning_rate=0.01, n_epochs=350, batch_size=64, verbose=True)
# Out:
# ... training
# training @ iter = 0
# training @ iter = 100
# training @ iter = 200
# training @ iter = 300
# training @ iter = 400
# training @ iter = 500
# training @ iter = 600
# training @ iter = 700
# epoch 1, minibatch 703/703, validation error 78.481721 %
#   epoch 1, minibatch 703/703, test error of best model 77.815066 %.
# training @ iter = 800
# training @ iter = 900
# training @ iter = 1000
# training @ iter = 1100
# training @ iter = 1200
# training @ iter = 1300
# training @ iter = 1400
# epoch 2, minibatch 703/703, validation error 74.093459 %
#   epoch 2, minibatch 703/703, test error of best model 60.742402 %.
# training @ iter = 1500
# training @ iter = 1600
# training @ iter = 1700
# training @ iter = 1800
# training @ iter = 1900
# training @ iter = 2000
# training @ iter = 2100
# epoch 3, minibatch 703/703, validation error 71.817096 %
#   epoch 3, minibatch 703/703, test error of best model 51.388648 %.
# training @ iter = 2200
# training @ iter = 2300
# ...
